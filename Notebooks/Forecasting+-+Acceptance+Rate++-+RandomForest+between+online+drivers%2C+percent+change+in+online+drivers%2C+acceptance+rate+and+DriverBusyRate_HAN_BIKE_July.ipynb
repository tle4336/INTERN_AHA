# %%
# A linear regression learning algorithm example using TensorFlow library.

from __future__ import print_function

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.contrib import learn
from sklearn import metrics
import random

rng = np.random

#read csv file
datapath = "./"
Ha_Noi = pd.read_csv(datapath+"OnlineDrivers_HaNoi_10days.csv")
#Add an additional column into the table
# sLength = len(Ha_Noi['accept_rate'])
Ha_Noi['accept_rate_timeT'] = pd.Series(Ha_Noi['accept_rate'], index=Ha_Noi.index)
Ha_Noi['online_drivers'] = pd.Series(Ha_Noi['online_drivers (no data on day 13 - 09:20:00)'], index=Ha_Noi.index)

#Shift the entries in the accept_rate column upward
Ha_Noi.accept_rate = Ha_Noi.accept_rate.shift(-1)
Ha_Noi['Pricing_timeT'] =  pd.Series(Ha_Noi['Pricing'], index=Ha_Noi.index)
Ha_Noi.Pricing = Ha_Noi.Pricing.shift(-1)

#Drop all the "na" entries in the original table
Ha_Noi = Ha_Noi.dropna(subset = ["longwait_percent4"])
Ha_Noi = Ha_Noi.dropna(subset=["accept_rate"])
Ha_Noi = Ha_Noi.dropna(subset = ["longwait_percent2"])
Ha_Noi = Ha_Noi.drop(Ha_Noi[Ha_Noi.Percentchange_onlinedrivers == 0].index)
Ha_Noi = Ha_Noi.dropna(subset = ["DriverBusyRate"])


#define normalized function for our dataset
# def normalize(array):
#     return (array - array.mean()) / array.std()

df2 = pd.DataFrame(Ha_Noi)


#split the dataset into training and testing sets
train_set, test_set = train_test_split(Ha_Noi, test_size=0.2, random_state = random.randint(20, 200))


# Training Data
train_X =  train_set[['accept_rate_timeT', 'longwait_percent3','Request/Supply', 'DriverBusyRate', 'Hour', 'wd1', 'wd2', 'wd3', 'wd4', 'wd5', 'wd6', 'wd7']]
train_Y =  train_set['accept_rate']

#Testing Data
Xtest = test_set[['accept_rate_timeT', 'longwait_percent3', 'Request/Supply', 'DriverBusyRate', 'Hour', 'wd1', 'wd2', 'wd3', 'wd4', 'wd5', 'wd6', 'wd7']]
Ytest = test_set['accept_rate']


#'longwait_percent2', 'accept_rate_timeT', 'Percentchange_onlinedrivers','DriverBusyRate'

# %% [markdown]
# Comment: This dataset is made up combining the queries from 3 cards: 1868, 1943, 1950. Since our system only saves the information of the last 10 days for Number of Online Drivers, which means we also only have the data for that many of days for DriverBusyRate, the author had to make up of the rest of the data by querying on successive days. The consequence is that the DriverBusyRate and Request/Supply could not be completely correct, which might be the reason why our RF model overfits. However, what is amazing is that our RF model still often predicts the trend of the acceptance rate *accurately*, even with such a noisy dataset!
#
# We choose all the features that have the highest positive correlations with Pricing based on the correlation testing obtained in the 3rd slide. This resulted in *7* features plus *2* obvious *lattitude features* to take into account the weekly and seasonality effects (i.e, Hour and Day of the week).
#
# The reason we decided to add the acceptance rate in the previous 20-mins is because of its strong negative correlations with pricing, which prevents the model from overfitting and *gives* it the ability to now when to *decrease* the price (as it's clear that pricing has strong negative correlation with acceptance rate in the previous 20-mins, at least based on our historical data from July 3rd to August 2nd). Without it, our best model - Random Forest Regressor - would always *increase* the price at the moment when we *actually* decreased it (we obtain this observation by testing our Random Forest Regression model with historical data). Also, we chose the factor "longwait_percent3" mainly due to its stronger negative correlation with pricing compared to other "longwait_percentX" factors (X = 2,3,4). Longwait_Percent3 is used to explain the fact that the later a request is made in the 20-min time interval, the more it matters to the acceptance rate in the next 20-min period. The formula to compute longwait_percent3 is in *card 1868* (https://bi.ahamove.com/question/1868?service_id=HAN-BIKE&time_interval=20&order_date=2017-06-04&end_date=2017-06-13). This factor is used to prevent our model from *overfitting*

# %%
# Parameters
num_epochs = 1000
STEPS = 150000
BATCH_SIZE = 80

#Deep Neural Network Regressor 
feature_column1 = learn.infer_real_valued_columns_from_input(train_X)
# feature_column2 = learn.infer_real_valued_columns_from_input(train_X2)
regressor = learn.DNNRegressor(feature_columns = feature_column1, hidden_units= [100,100], model_dir = "./AR3")
regressor.fit(train_X, train_Y, max_steps= STEPS, batch_size= BATCH_SIZE)
Ypred = regressor.predict_scores(Xtest, as_iterable=False)
Ypred = np.asarray(list(Ypred))
rmse = np.sqrt(((Ypred - Ytest) ** 2).mean(axis=0))
print("Root mean square Error: %.3f" %rmse)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9438fed550>, '_model_dir': './AR3', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': None, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_evaluation_master': '', '_master': ''}
# WARNING:tensorflow:From <ipython-input-38-9ac2a927eaa3>:10: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-38-9ac2a927eaa3>:10: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-38-9ac2a927eaa3>:10: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./AR3/model.ckpt.
# INFO:tensorflow:loss = 0.519509, step = 1
# INFO:tensorflow:global_step/sec: 236.144
# INFO:tensorflow:loss = 0.00308055, step = 101 (0.425 sec)
# INFO:tensorflow:global_step/sec: 235.901
# INFO:tensorflow:loss = 0.00349743, step = 201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 246.746
# INFO:tensorflow:loss = 0.00665445, step = 301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 237.476
# INFO:tensorflow:loss = 0.00284431, step = 401 (0.421 sec)
# INFO:tensorflow:global_step/sec: 249.275
# INFO:tensorflow:loss = 0.00257095, step = 501 (0.401 sec)
# INFO:tensorflow:global_step/sec: 247.538
# INFO:tensorflow:loss = 0.00524172, step = 601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 206.859
# INFO:tensorflow:loss = 0.00307295, step = 701 (0.480 sec)
# INFO:tensorflow:global_step/sec: 208.907
# INFO:tensorflow:loss = 0.0033954, step = 801 (0.479 sec)
# INFO:tensorflow:global_step/sec: 228.203
# INFO:tensorflow:loss = 0.00719903, step = 901 (0.439 sec)
# INFO:tensorflow:global_step/sec: 234.39
# INFO:tensorflow:loss = 0.00330431, step = 1001 (0.428 sec)
# INFO:tensorflow:global_step/sec: 240.47
# INFO:tensorflow:loss = 0.00417115, step = 1101 (0.415 sec)
# INFO:tensorflow:global_step/sec: 176.859
# INFO:tensorflow:loss = 0.0112559, step = 1201 (0.565 sec)
# INFO:tensorflow:global_step/sec: 205.503
# INFO:tensorflow:loss = 0.00332135, step = 1301 (0.489 sec)
# INFO:tensorflow:global_step/sec: 180.503
# INFO:tensorflow:loss = 0.00371989, step = 1401 (0.552 sec)
# INFO:tensorflow:global_step/sec: 204.861
# INFO:tensorflow:loss = 0.00702412, step = 1501 (0.489 sec)
# INFO:tensorflow:global_step/sec: 225.375
# INFO:tensorflow:loss = 0.00239601, step = 1601 (0.444 sec)
# INFO:tensorflow:global_step/sec: 246.396
# INFO:tensorflow:loss = 0.00412996, step = 1701 (0.405 sec)
# INFO:tensorflow:global_step/sec: 190.19
# INFO:tensorflow:loss = 0.00437069, step = 1801 (0.526 sec)
# INFO:tensorflow:global_step/sec: 234.111
# INFO:tensorflow:loss = 0.00426031, step = 1901 (0.427 sec)
# INFO:tensorflow:global_step/sec: 231.974
# INFO:tensorflow:loss = 0.0028339, step = 2001 (0.431 sec)
# INFO:tensorflow:global_step/sec: 212.808
# INFO:tensorflow:loss = 0.00640304, step = 2101 (0.470 sec)
# INFO:tensorflow:global_step/sec: 189.188
# INFO:tensorflow:loss = 0.0034294, step = 2201 (0.528 sec)
# INFO:tensorflow:global_step/sec: 224.122
# INFO:tensorflow:loss = 0.00427303, step = 2301 (0.447 sec)
# INFO:tensorflow:global_step/sec: 219.953
# INFO:tensorflow:loss = 0.0100991, step = 2401 (0.454 sec)
# INFO:tensorflow:global_step/sec: 229.454
# INFO:tensorflow:loss = 0.00372606, step = 2501 (0.438 sec)
# INFO:tensorflow:global_step/sec: 214.649
# INFO:tensorflow:loss = 0.0035815, step = 2601 (0.464 sec)
# INFO:tensorflow:global_step/sec: 222.399
# INFO:tensorflow:loss = 0.00457684, step = 2701 (0.453 sec)
# INFO:tensorflow:global_step/sec: 213.091
# INFO:tensorflow:loss = 0.00273176, step = 2801 (0.468 sec)
# INFO:tensorflow:global_step/sec: 195.459
# INFO:tensorflow:loss = 0.00437888, step = 2901 (0.510 sec)
# INFO:tensorflow:global_step/sec: 243.192
# INFO:tensorflow:loss = 0.00254409, step = 3001 (0.413 sec)
# INFO:tensorflow:global_step/sec: 237.025
# INFO:tensorflow:loss = 0.00323154, step = 3101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 228.778
# INFO:tensorflow:loss = 0.00272138, step = 3201 (0.436 sec)
# INFO:tensorflow:global_step/sec: 233.664
# INFO:tensorflow:loss = 0.00330634, step = 3301 (0.430 sec)
# INFO:tensorflow:global_step/sec: 211.719
# INFO:tensorflow:loss = 0.00430323, step = 3401 (0.470 sec)
# INFO:tensorflow:global_step/sec: 220.86
# INFO:tensorflow:loss = 0.00332339, step = 3501 (0.453 sec)
# INFO:tensorflow:global_step/sec: 216.168
# INFO:tensorflow:loss = 0.00384146, step = 3601 (0.466 sec)
# INFO:tensorflow:global_step/sec: 250.718
# INFO:tensorflow:loss = 0.00285134, step = 3701 (0.395 sec)
# INFO:tensorflow:global_step/sec: 197.764
# INFO:tensorflow:loss = 0.00307682, step = 3801 (0.509 sec)
# INFO:tensorflow:global_step/sec: 201.127
# INFO:tensorflow:loss = 0.00495411, step = 3901 (0.494 sec)
# INFO:tensorflow:global_step/sec: 178.13
# INFO:tensorflow:loss = 0.00362099, step = 4001 (0.563 sec)
# INFO:tensorflow:global_step/sec: 212.159
# INFO:tensorflow:loss = 0.00295081, step = 4101 (0.471 sec)
# INFO:tensorflow:global_step/sec: 180.452
# INFO:tensorflow:loss = 0.00360723, step = 4201 (0.554 sec)
# INFO:tensorflow:global_step/sec: 205.768
# INFO:tensorflow:loss = 0.00288352, step = 4301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 215.296
# INFO:tensorflow:loss = 0.00281031, step = 4401 (0.468 sec)
# INFO:tensorflow:global_step/sec: 210.772
# INFO:tensorflow:loss = 0.0043773, step = 4501 (0.471 sec)
# INFO:tensorflow:global_step/sec: 169.719
# INFO:tensorflow:loss = 0.00441176, step = 4601 (0.589 sec)
# INFO:tensorflow:global_step/sec: 175.606
# INFO:tensorflow:loss = 0.0044864, step = 4701 (0.573 sec)
# INFO:tensorflow:global_step/sec: 217.843
# INFO:tensorflow:loss = 0.0039864, step = 4801 (0.455 sec)
# INFO:tensorflow:global_step/sec: 195.28
# INFO:tensorflow:loss = 0.00377836, step = 4901 (0.512 sec)
# INFO:tensorflow:global_step/sec: 201.906
# INFO:tensorflow:loss = 0.00447128, step = 5001 (0.496 sec)
# INFO:tensorflow:global_step/sec: 217.874
# INFO:tensorflow:loss = 0.00502593, step = 5101 (0.458 sec)
# INFO:tensorflow:global_step/sec: 186.027
# INFO:tensorflow:loss = 0.00257515, step = 5201 (0.537 sec)
# INFO:tensorflow:global_step/sec: 191.108
# INFO:tensorflow:loss = 0.00479797, step = 5301 (0.524 sec)
# INFO:tensorflow:global_step/sec: 229.751
# INFO:tensorflow:loss = 0.00296212, step = 5401 (0.435 sec)
# INFO:tensorflow:global_step/sec: 213.366
# INFO:tensorflow:loss = 0.0025869, step = 5501 (0.470 sec)
# INFO:tensorflow:global_step/sec: 198.817
# INFO:tensorflow:loss = 0.00418669, step = 5601 (0.501 sec)
# INFO:tensorflow:global_step/sec: 224.183
# INFO:tensorflow:loss = 0.00941251, step = 5701 (0.447 sec)
# INFO:tensorflow:global_step/sec: 218.402
# INFO:tensorflow:loss = 0.00357046, step = 5801 (0.458 sec)
# INFO:tensorflow:global_step/sec: 216.65
# INFO:tensorflow:loss = 0.00462269, step = 5901 (0.463 sec)
# INFO:tensorflow:global_step/sec: 225.419
# INFO:tensorflow:loss = 0.00269474, step = 6001 (0.442 sec)
# INFO:tensorflow:global_step/sec: 232.129
# INFO:tensorflow:loss = 0.00626478, step = 6101 (0.431 sec)
# INFO:tensorflow:global_step/sec: 207.998
# INFO:tensorflow:loss = 0.00497049, step = 6201 (0.481 sec)
# INFO:tensorflow:global_step/sec: 255.007
# INFO:tensorflow:loss = 0.00369909, step = 6301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 249.887
# INFO:tensorflow:loss = 0.0033785, step = 6401 (0.400 sec)
# INFO:tensorflow:global_step/sec: 199.417
# INFO:tensorflow:loss = 0.00411595, step = 6501 (0.502 sec)
# INFO:tensorflow:global_step/sec: 208.745
# INFO:tensorflow:loss = 0.00262796, step = 6601 (0.478 sec)
# INFO:tensorflow:global_step/sec: 233.764
# INFO:tensorflow:loss = 0.00390697, step = 6701 (0.430 sec)
# INFO:tensorflow:global_step/sec: 227.507
# INFO:tensorflow:loss = 0.0031472, step = 6801 (0.438 sec)
# INFO:tensorflow:global_step/sec: 227.06
# INFO:tensorflow:loss = 0.00345422, step = 6901 (0.440 sec)
# INFO:tensorflow:global_step/sec: 202.179
# INFO:tensorflow:loss = 0.00396423, step = 7001 (0.495 sec)
# INFO:tensorflow:global_step/sec: 216.738
# INFO:tensorflow:loss = 0.00279865, step = 7101 (0.461 sec)
# INFO:tensorflow:global_step/sec: 214.979
# INFO:tensorflow:loss = 0.00466039, step = 7201 (0.466 sec)
# INFO:tensorflow:global_step/sec: 247.204
# INFO:tensorflow:loss = 0.00456833, step = 7301 (0.404 sec)
# INFO:tensorflow:global_step/sec: 221.478
# INFO:tensorflow:loss = 0.00268507, step = 7401 (0.452 sec)
# INFO:tensorflow:global_step/sec: 195.493
# INFO:tensorflow:loss = 0.00296203, step = 7501 (0.511 sec)
# INFO:tensorflow:global_step/sec: 245.001
# INFO:tensorflow:loss = 0.00313805, step = 7601 (0.408 sec)
# INFO:tensorflow:global_step/sec: 227.506
# INFO:tensorflow:loss = 0.0047817, step = 7701 (0.440 sec)
# INFO:tensorflow:global_step/sec: 226.714
# INFO:tensorflow:loss = 0.00249778, step = 7801 (0.441 sec)
# INFO:tensorflow:global_step/sec: 231.989
# INFO:tensorflow:loss = 0.00298397, step = 7901 (0.431 sec)
# INFO:tensorflow:global_step/sec: 221.05
# INFO:tensorflow:loss = 0.00285231, step = 8001 (0.452 sec)
# INFO:tensorflow:global_step/sec: 219.671
# INFO:tensorflow:loss = 0.00416942, step = 8101 (0.455 sec)
# INFO:tensorflow:global_step/sec: 198.905
# INFO:tensorflow:loss = 0.00467489, step = 8201 (0.502 sec)
# INFO:tensorflow:global_step/sec: 228.497
# INFO:tensorflow:loss = 0.00390191, step = 8301 (0.438 sec)
# INFO:tensorflow:global_step/sec: 235.281
# INFO:tensorflow:loss = 0.00282207, step = 8401 (0.425 sec)
# INFO:tensorflow:global_step/sec: 209.905
# INFO:tensorflow:loss = 0.00324979, step = 8501 (0.476 sec)
# INFO:tensorflow:global_step/sec: 220.42
# INFO:tensorflow:loss = 0.00394853, step = 8601 (0.454 sec)
# INFO:tensorflow:global_step/sec: 235.098
# INFO:tensorflow:loss = 0.00680453, step = 8701 (0.425 sec)
# INFO:tensorflow:global_step/sec: 227.616
# INFO:tensorflow:loss = 0.00281991, step = 8801 (0.439 sec)
# INFO:tensorflow:global_step/sec: 214.273
# INFO:tensorflow:loss = 0.00397302, step = 8901 (0.467 sec)
# INFO:tensorflow:global_step/sec: 219.842
# INFO:tensorflow:loss = 0.00564426, step = 9001 (0.455 sec)
# INFO:tensorflow:global_step/sec: 179.804
# INFO:tensorflow:loss = 0.00487029, step = 9101 (0.556 sec)
# INFO:tensorflow:global_step/sec: 236.601
# INFO:tensorflow:loss = 0.00263001, step = 9201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 237.228
# INFO:tensorflow:loss = 0.00355514, step = 9301 (0.422 sec)
# INFO:tensorflow:global_step/sec: 235.759
# INFO:tensorflow:loss = 0.00258099, step = 9401 (0.427 sec)
# INFO:tensorflow:global_step/sec: 235.01
# INFO:tensorflow:loss = 0.00338322, step = 9501 (0.425 sec)
# INFO:tensorflow:global_step/sec: 249.727
# INFO:tensorflow:loss = 0.00404408, step = 9601 (0.398 sec)
# INFO:tensorflow:global_step/sec: 211.204
# INFO:tensorflow:loss = 0.00350096, step = 9701 (0.473 sec)
# INFO:tensorflow:global_step/sec: 190.68
# INFO:tensorflow:loss = 0.00284848, step = 9801 (0.525 sec)
# INFO:tensorflow:global_step/sec: 224.208
# INFO:tensorflow:loss = 0.00574192, step = 9901 (0.446 sec)
# INFO:tensorflow:global_step/sec: 211.22
# INFO:tensorflow:loss = 0.00234781, step = 10001 (0.475 sec)
# INFO:tensorflow:global_step/sec: 226.934
# INFO:tensorflow:loss = 0.00350878, step = 10101 (0.441 sec)
# INFO:tensorflow:global_step/sec: 213.702
# INFO:tensorflow:loss = 0.00287092, step = 10201 (0.466 sec)
# INFO:tensorflow:global_step/sec: 226.421
# INFO:tensorflow:loss = 0.00364318, step = 10301 (0.442 sec)
# INFO:tensorflow:global_step/sec: 216.608
# INFO:tensorflow:loss = 0.004539, step = 10401 (0.464 sec)
# INFO:tensorflow:global_step/sec: 239.572
# INFO:tensorflow:loss = 0.00486567, step = 10501 (0.414 sec)
# INFO:tensorflow:global_step/sec: 231.008
# INFO:tensorflow:loss = 0.00405292, step = 10601 (0.433 sec)
# INFO:tensorflow:global_step/sec: 239.899
# INFO:tensorflow:loss = 0.00289093, step = 10701 (0.418 sec)
# INFO:tensorflow:global_step/sec: 234.093
# INFO:tensorflow:loss = 0.00380962, step = 10801 (0.427 sec)
# INFO:tensorflow:global_step/sec: 229.361
# INFO:tensorflow:loss = 0.00348193, step = 10901 (0.435 sec)
# INFO:tensorflow:global_step/sec: 199.769
# INFO:tensorflow:loss = 0.00340745, step = 11001 (0.502 sec)
# INFO:tensorflow:global_step/sec: 253.73
# INFO:tensorflow:loss = 0.00528326, step = 11101 (0.393 sec)
# INFO:tensorflow:global_step/sec: 230.767
# INFO:tensorflow:loss = 0.00283231, step = 11201 (0.433 sec)
# INFO:tensorflow:global_step/sec: 235.972
# INFO:tensorflow:loss = 0.00228003, step = 11301 (0.424 sec)
# INFO:tensorflow:global_step/sec: 243.149
# INFO:tensorflow:loss = 0.00505729, step = 11401 (0.411 sec)
# INFO:tensorflow:global_step/sec: 232.363
# INFO:tensorflow:loss = 0.00312835, step = 11501 (0.430 sec)
# INFO:tensorflow:global_step/sec: 236.045
# INFO:tensorflow:loss = 0.00333602, step = 11601 (0.424 sec)
# INFO:tensorflow:global_step/sec: 274.937
# INFO:tensorflow:loss = 0.00315091, step = 11701 (0.365 sec)
# INFO:tensorflow:global_step/sec: 215.235
# INFO:tensorflow:loss = 0.00480059, step = 11801 (0.467 sec)
# INFO:tensorflow:global_step/sec: 230.508
# INFO:tensorflow:loss = 0.00302748, step = 11901 (0.431 sec)
# INFO:tensorflow:global_step/sec: 219.56
# INFO:tensorflow:loss = 0.0026666, step = 12001 (0.455 sec)
# INFO:tensorflow:global_step/sec: 248.264
# INFO:tensorflow:loss = 0.00265873, step = 12101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 268.529
# INFO:tensorflow:loss = 0.00505287, step = 12201 (0.371 sec)
# INFO:tensorflow:global_step/sec: 237.388
# INFO:tensorflow:loss = 0.00268942, step = 12301 (0.421 sec)
# INFO:tensorflow:global_step/sec: 247.791
# INFO:tensorflow:loss = 0.00469652, step = 12401 (0.403 sec)
# INFO:tensorflow:global_step/sec: 229.324
# INFO:tensorflow:loss = 0.00346949, step = 12501 (0.436 sec)
# INFO:tensorflow:global_step/sec: 232.156
# INFO:tensorflow:loss = 0.0046115, step = 12601 (0.433 sec)
# INFO:tensorflow:global_step/sec: 216.72
# INFO:tensorflow:loss = 0.00478899, step = 12701 (0.462 sec)
# INFO:tensorflow:global_step/sec: 225.793
# INFO:tensorflow:loss = 0.00448844, step = 12801 (0.441 sec)
# INFO:tensorflow:global_step/sec: 210.714
# INFO:tensorflow:loss = 0.00388258, step = 12901 (0.474 sec)
# INFO:tensorflow:global_step/sec: 224.207
# INFO:tensorflow:loss = 0.00332612, step = 13001 (0.445 sec)
# INFO:tensorflow:global_step/sec: 259.365
# INFO:tensorflow:loss = 0.0032061, step = 13101 (0.386 sec)
# INFO:tensorflow:global_step/sec: 205.76
# INFO:tensorflow:loss = 0.00344741, step = 13201 (0.488 sec)
# INFO:tensorflow:global_step/sec: 207.742
# INFO:tensorflow:loss = 0.00340472, step = 13301 (0.481 sec)
# INFO:tensorflow:global_step/sec: 198.932
# INFO:tensorflow:loss = 0.00462006, step = 13401 (0.500 sec)
# INFO:tensorflow:global_step/sec: 234.569
# INFO:tensorflow:loss = 0.00446535, step = 13501 (0.429 sec)
# INFO:tensorflow:global_step/sec: 230.8
# INFO:tensorflow:loss = 0.00341082, step = 13601 (0.431 sec)
# INFO:tensorflow:global_step/sec: 175.84
# INFO:tensorflow:loss = 0.00273174, step = 13701 (0.569 sec)
# INFO:tensorflow:global_step/sec: 234.54
# INFO:tensorflow:loss = 0.00275252, step = 13801 (0.426 sec)
# INFO:tensorflow:global_step/sec: 226.639
# INFO:tensorflow:loss = 0.00402048, step = 13901 (0.442 sec)
# INFO:tensorflow:global_step/sec: 202.489
# INFO:tensorflow:loss = 0.00259799, step = 14001 (0.493 sec)
# INFO:tensorflow:global_step/sec: 235.193
# INFO:tensorflow:loss = 0.00466792, step = 14101 (0.427 sec)
# INFO:tensorflow:global_step/sec: 249.738
# INFO:tensorflow:loss = 0.00384944, step = 14201 (0.400 sec)
# INFO:tensorflow:global_step/sec: 212.033
# INFO:tensorflow:loss = 0.00477467, step = 14301 (0.470 sec)
# INFO:tensorflow:global_step/sec: 237.056
# INFO:tensorflow:loss = 0.00350305, step = 14401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 226.009
# INFO:tensorflow:loss = 0.00276523, step = 14501 (0.443 sec)
# INFO:tensorflow:global_step/sec: 200.39
# INFO:tensorflow:loss = 0.00329898, step = 14601 (0.499 sec)
# INFO:tensorflow:global_step/sec: 250.659
# INFO:tensorflow:loss = 0.00372661, step = 14701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 199.443
# INFO:tensorflow:loss = 0.00258547, step = 14801 (0.503 sec)
# INFO:tensorflow:global_step/sec: 251.077
# INFO:tensorflow:loss = 0.00236681, step = 14901 (0.397 sec)
# INFO:tensorflow:global_step/sec: 208.355
# INFO:tensorflow:loss = 0.00233749, step = 15001 (0.482 sec)
# INFO:tensorflow:global_step/sec: 205.39
# INFO:tensorflow:loss = 0.00252109, step = 15101 (0.485 sec)
# INFO:tensorflow:global_step/sec: 221.849
# INFO:tensorflow:loss = 0.00323324, step = 15201 (0.452 sec)
# INFO:tensorflow:global_step/sec: 189.356
# INFO:tensorflow:loss = 0.00402438, step = 15301 (0.527 sec)
# INFO:tensorflow:global_step/sec: 192.389
# INFO:tensorflow:loss = 0.00498256, step = 15401 (0.520 sec)
# INFO:tensorflow:global_step/sec: 223.151
# INFO:tensorflow:loss = 0.00301186, step = 15501 (0.448 sec)
# INFO:tensorflow:global_step/sec: 214.395
# INFO:tensorflow:loss = 0.00268639, step = 15601 (0.466 sec)
# INFO:tensorflow:global_step/sec: 233.534
# INFO:tensorflow:loss = 0.00395882, step = 15701 (0.428 sec)
# INFO:tensorflow:global_step/sec: 228.789
# INFO:tensorflow:loss = 0.00420246, step = 15801 (0.437 sec)
# INFO:tensorflow:global_step/sec: 252.505
# INFO:tensorflow:loss = 0.00277054, step = 15901 (0.396 sec)
# INFO:tensorflow:global_step/sec: 253.691
# INFO:tensorflow:loss = 0.00407275, step = 16001 (0.395 sec)
# INFO:tensorflow:global_step/sec: 258.86
# INFO:tensorflow:loss = 0.0036939, step = 16101 (0.386 sec)
# INFO:tensorflow:global_step/sec: 238.756
# INFO:tensorflow:loss = 0.00792748, step = 16201 (0.419 sec)
# INFO:tensorflow:global_step/sec: 225.737
# INFO:tensorflow:loss = 0.00359096, step = 16301 (0.446 sec)
# INFO:tensorflow:global_step/sec: 233.003
# INFO:tensorflow:loss = 0.00259957, step = 16401 (0.426 sec)
# INFO:tensorflow:global_step/sec: 218.734
# INFO:tensorflow:loss = 0.00452612, step = 16501 (0.458 sec)
# INFO:tensorflow:global_step/sec: 223.381
# INFO:tensorflow:loss = 0.00353874, step = 16601 (0.450 sec)
# INFO:tensorflow:global_step/sec: 208.303
# INFO:tensorflow:loss = 0.00390574, step = 16701 (0.478 sec)
# INFO:tensorflow:global_step/sec: 243.055
# INFO:tensorflow:loss = 0.00412603, step = 16801 (0.411 sec)
# INFO:tensorflow:global_step/sec: 266.936
# INFO:tensorflow:loss = 0.00364088, step = 16901 (0.375 sec)
# INFO:tensorflow:global_step/sec: 239.437
# INFO:tensorflow:loss = 0.00276613, step = 17001 (0.418 sec)
# INFO:tensorflow:global_step/sec: 186.756
# INFO:tensorflow:loss = 0.0033004, step = 17101 (0.538 sec)
# INFO:tensorflow:global_step/sec: 252.849
# INFO:tensorflow:loss = 0.00349982, step = 17201 (0.392 sec)
# INFO:tensorflow:global_step/sec: 238.231
# INFO:tensorflow:loss = 0.00194863, step = 17301 (0.422 sec)
# INFO:tensorflow:global_step/sec: 205.708
# INFO:tensorflow:loss = 0.00251968, step = 17401 (0.485 sec)
# INFO:tensorflow:global_step/sec: 234.974
# INFO:tensorflow:loss = 0.00320705, step = 17501 (0.427 sec)
# INFO:tensorflow:global_step/sec: 209.585
# INFO:tensorflow:loss = 0.00347488, step = 17601 (0.475 sec)
# INFO:tensorflow:global_step/sec: 254.719
# INFO:tensorflow:loss = 0.00517313, step = 17701 (0.393 sec)
# INFO:tensorflow:global_step/sec: 213.557
# INFO:tensorflow:loss = 0.00350961, step = 17801 (0.468 sec)
# INFO:tensorflow:global_step/sec: 246.293
# INFO:tensorflow:loss = 0.00370759, step = 17901 (0.406 sec)
# INFO:tensorflow:global_step/sec: 245.428
# INFO:tensorflow:loss = 0.00477895, step = 18001 (0.408 sec)
# INFO:tensorflow:global_step/sec: 251.037
# INFO:tensorflow:loss = 0.00403219, step = 18101 (0.399 sec)
# INFO:tensorflow:global_step/sec: 236.167
# INFO:tensorflow:loss = 0.00375945, step = 18201 (0.424 sec)
# INFO:tensorflow:global_step/sec: 225.535
# INFO:tensorflow:loss = 0.0038263, step = 18301 (0.443 sec)
# INFO:tensorflow:global_step/sec: 234.695
# INFO:tensorflow:loss = 0.00364559, step = 18401 (0.427 sec)
# INFO:tensorflow:global_step/sec: 183.447
# INFO:tensorflow:loss = 0.0030992, step = 18501 (0.546 sec)
# INFO:tensorflow:global_step/sec: 182.14
# INFO:tensorflow:loss = 0.002655, step = 18601 (0.547 sec)
# INFO:tensorflow:global_step/sec: 224.249
# INFO:tensorflow:loss = 0.00377566, step = 18701 (0.447 sec)
# INFO:tensorflow:global_step/sec: 224.992
# INFO:tensorflow:loss = 0.00382827, step = 18801 (0.444 sec)
# INFO:tensorflow:global_step/sec: 184.944
# INFO:tensorflow:loss = 0.0052655, step = 18901 (0.541 sec)
# INFO:tensorflow:global_step/sec: 202.035
# INFO:tensorflow:loss = 0.00270673, step = 19001 (0.494 sec)
# INFO:tensorflow:global_step/sec: 252.811
# INFO:tensorflow:loss = 0.00371645, step = 19101 (0.395 sec)
# INFO:tensorflow:global_step/sec: 210.294
# INFO:tensorflow:loss = 0.00328301, step = 19201 (0.479 sec)
# INFO:tensorflow:global_step/sec: 192.836
# INFO:tensorflow:loss = 0.00334055, step = 19301 (0.516 sec)
# INFO:tensorflow:global_step/sec: 197.998
# INFO:tensorflow:loss = 0.00493972, step = 19401 (0.505 sec)
# INFO:tensorflow:global_step/sec: 193.418
# INFO:tensorflow:loss = 0.00299194, step = 19501 (0.517 sec)
# INFO:tensorflow:global_step/sec: 208.309
# INFO:tensorflow:loss = 0.00237413, step = 19601 (0.480 sec)
# INFO:tensorflow:global_step/sec: 224.689
# INFO:tensorflow:loss = 0.00393387, step = 19701 (0.445 sec)
# INFO:tensorflow:global_step/sec: 243.763
# INFO:tensorflow:loss = 0.0035163, step = 19801 (0.410 sec)
# INFO:tensorflow:global_step/sec: 219.985
# INFO:tensorflow:loss = 0.00443237, step = 19901 (0.456 sec)
# INFO:tensorflow:global_step/sec: 211.237
# INFO:tensorflow:loss = 0.00365888, step = 20001 (0.473 sec)
# INFO:tensorflow:global_step/sec: 193.196
# INFO:tensorflow:loss = 0.00496041, step = 20101 (0.517 sec)
# INFO:tensorflow:global_step/sec: 227.426
# INFO:tensorflow:loss = 0.0035581, step = 20201 (0.445 sec)
# INFO:tensorflow:global_step/sec: 248.098
# INFO:tensorflow:loss = 0.00273572, step = 20301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 215.58
# INFO:tensorflow:loss = 0.00316157, step = 20401 (0.464 sec)
# INFO:tensorflow:global_step/sec: 227.267
# INFO:tensorflow:loss = 0.00329659, step = 20501 (0.440 sec)
# INFO:tensorflow:global_step/sec: 218.566
# INFO:tensorflow:loss = 0.0036608, step = 20601 (0.457 sec)
# INFO:tensorflow:global_step/sec: 222.82
# INFO:tensorflow:loss = 0.00368841, step = 20701 (0.449 sec)
# INFO:tensorflow:global_step/sec: 214.064
# INFO:tensorflow:loss = 0.00243658, step = 20801 (0.468 sec)
# INFO:tensorflow:global_step/sec: 251.237
# INFO:tensorflow:loss = 0.00294228, step = 20901 (0.397 sec)
# INFO:tensorflow:global_step/sec: 234.909
# INFO:tensorflow:loss = 0.00355186, step = 21001 (0.426 sec)
# INFO:tensorflow:global_step/sec: 199.955
# INFO:tensorflow:loss = 0.00271265, step = 21101 (0.500 sec)
# INFO:tensorflow:global_step/sec: 221.967
# INFO:tensorflow:loss = 0.00369895, step = 21201 (0.450 sec)
# INFO:tensorflow:global_step/sec: 245.656
# INFO:tensorflow:loss = 0.00341869, step = 21301 (0.407 sec)
# INFO:tensorflow:global_step/sec: 199.755
# INFO:tensorflow:loss = 0.0024986, step = 21401 (0.500 sec)
# INFO:tensorflow:global_step/sec: 216.443
# INFO:tensorflow:loss = 0.00408743, step = 21501 (0.462 sec)
# INFO:tensorflow:global_step/sec: 240.071
# INFO:tensorflow:loss = 0.0155604, step = 21601 (0.417 sec)
# INFO:tensorflow:global_step/sec: 206.33
# INFO:tensorflow:loss = 0.00335909, step = 21701 (0.487 sec)
# INFO:tensorflow:global_step/sec: 206.031
# INFO:tensorflow:loss = 0.00249002, step = 21801 (0.486 sec)
# INFO:tensorflow:global_step/sec: 241.888
# INFO:tensorflow:loss = 0.00325247, step = 21901 (0.411 sec)
# INFO:tensorflow:global_step/sec: 226.05
# INFO:tensorflow:loss = 0.00302526, step = 22001 (0.445 sec)
# INFO:tensorflow:global_step/sec: 189.219
# INFO:tensorflow:loss = 0.00283946, step = 22101 (0.526 sec)
# INFO:tensorflow:global_step/sec: 213.964
# INFO:tensorflow:loss = 0.00290987, step = 22201 (0.468 sec)
# INFO:tensorflow:global_step/sec: 243.919
# INFO:tensorflow:loss = 0.00405336, step = 22301 (0.409 sec)
# INFO:tensorflow:global_step/sec: 195.505
# INFO:tensorflow:loss = 0.00304727, step = 22401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 181.919
# INFO:tensorflow:loss = 0.00492898, step = 22501 (0.549 sec)
# INFO:tensorflow:global_step/sec: 238.833
# INFO:tensorflow:loss = 0.00322015, step = 22601 (0.419 sec)
# INFO:tensorflow:global_step/sec: 188.84
# INFO:tensorflow:loss = 0.00500976, step = 22701 (0.530 sec)
# INFO:tensorflow:global_step/sec: 183.114
# INFO:tensorflow:loss = 0.00287425, step = 22801 (0.546 sec)
# INFO:tensorflow:global_step/sec: 200.198
# INFO:tensorflow:loss = 0.00488846, step = 22901 (0.500 sec)
# INFO:tensorflow:global_step/sec: 202.832
# INFO:tensorflow:loss = 0.00345454, step = 23001 (0.493 sec)
# INFO:tensorflow:global_step/sec: 238.534
# INFO:tensorflow:loss = 0.00553023, step = 23101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 213.752
# INFO:tensorflow:loss = 0.0027194, step = 23201 (0.467 sec)
# INFO:tensorflow:global_step/sec: 204.185
# INFO:tensorflow:loss = 0.00373358, step = 23301 (0.490 sec)
# INFO:tensorflow:global_step/sec: 165.151
# INFO:tensorflow:loss = 0.00368667, step = 23401 (0.608 sec)
# INFO:tensorflow:global_step/sec: 218.387
# INFO:tensorflow:loss = 0.00372792, step = 23501 (0.457 sec)
# INFO:tensorflow:global_step/sec: 247.695
# INFO:tensorflow:loss = 0.00417343, step = 23601 (0.401 sec)
# INFO:tensorflow:global_step/sec: 228.374
# INFO:tensorflow:loss = 0.00310142, step = 23701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 212.597
# INFO:tensorflow:loss = 0.00487319, step = 23801 (0.474 sec)
# INFO:tensorflow:global_step/sec: 249.504
# INFO:tensorflow:loss = 0.00358012, step = 23901 (0.396 sec)
# INFO:tensorflow:global_step/sec: 206.093
# INFO:tensorflow:loss = 0.00452699, step = 24001 (0.483 sec)
# INFO:tensorflow:global_step/sec: 222.717
# INFO:tensorflow:loss = 0.00289144, step = 24101 (0.449 sec)
# INFO:tensorflow:global_step/sec: 177.361
# INFO:tensorflow:loss = 0.00279246, step = 24201 (0.565 sec)
# INFO:tensorflow:global_step/sec: 198.852
# INFO:tensorflow:loss = 0.00352945, step = 24301 (0.502 sec)
# INFO:tensorflow:global_step/sec: 250.534
# INFO:tensorflow:loss = 0.00358057, step = 24401 (0.399 sec)
# INFO:tensorflow:global_step/sec: 240.666
# INFO:tensorflow:loss = 0.00306387, step = 24501 (0.417 sec)
# INFO:tensorflow:global_step/sec: 227.47
# INFO:tensorflow:loss = 0.00509041, step = 24601 (0.438 sec)
# INFO:tensorflow:global_step/sec: 235.899
# INFO:tensorflow:loss = 0.00378455, step = 24701 (0.424 sec)
# INFO:tensorflow:global_step/sec: 216.078
# INFO:tensorflow:loss = 0.00304233, step = 24801 (0.465 sec)
# INFO:tensorflow:global_step/sec: 177.035
# INFO:tensorflow:loss = 0.00340378, step = 24901 (0.566 sec)
# INFO:tensorflow:global_step/sec: 216.419
# INFO:tensorflow:loss = 0.00272898, step = 25001 (0.459 sec)
# INFO:tensorflow:global_step/sec: 212.743
# INFO:tensorflow:loss = 0.00389464, step = 25101 (0.470 sec)
# INFO:tensorflow:global_step/sec: 211.864
# INFO:tensorflow:loss = 0.00406162, step = 25201 (0.472 sec)
# INFO:tensorflow:global_step/sec: 233.005
# INFO:tensorflow:loss = 0.00346118, step = 25301 (0.429 sec)
# INFO:tensorflow:global_step/sec: 244.4
# INFO:tensorflow:loss = 0.00181665, step = 25401 (0.411 sec)
# INFO:tensorflow:global_step/sec: 192.24
# INFO:tensorflow:loss = 0.00483165, step = 25501 (0.519 sec)
# INFO:tensorflow:global_step/sec: 233.951
# INFO:tensorflow:loss = 0.00285578, step = 25601 (0.427 sec)
# INFO:tensorflow:global_step/sec: 203.17
# INFO:tensorflow:loss = 0.00257016, step = 25701 (0.492 sec)
# INFO:tensorflow:global_step/sec: 259.771
# INFO:tensorflow:loss = 0.00473533, step = 25801 (0.386 sec)
# INFO:tensorflow:global_step/sec: 209.103
# INFO:tensorflow:loss = 0.00371562, step = 25901 (0.478 sec)
# INFO:tensorflow:global_step/sec: 207.04
# INFO:tensorflow:loss = 0.00267064, step = 26001 (0.484 sec)
# INFO:tensorflow:global_step/sec: 202.892
# INFO:tensorflow:loss = 0.00291729, step = 26101 (0.492 sec)
# INFO:tensorflow:global_step/sec: 247.967
# INFO:tensorflow:loss = 0.00236098, step = 26201 (0.403 sec)
# INFO:tensorflow:global_step/sec: 209.6
# INFO:tensorflow:loss = 0.00401726, step = 26301 (0.478 sec)
# INFO:tensorflow:global_step/sec: 229.226
# INFO:tensorflow:loss = 0.00364597, step = 26401 (0.435 sec)
# INFO:tensorflow:global_step/sec: 206.264
# INFO:tensorflow:loss = 0.00386329, step = 26501 (0.485 sec)
# INFO:tensorflow:global_step/sec: 216.964
# INFO:tensorflow:loss = 0.0026447, step = 26601 (0.461 sec)
# INFO:tensorflow:global_step/sec: 247.755
# INFO:tensorflow:loss = 0.00427664, step = 26701 (0.403 sec)
# INFO:tensorflow:global_step/sec: 221.364
# INFO:tensorflow:loss = 0.00421466, step = 26801 (0.452 sec)
# INFO:tensorflow:global_step/sec: 222.756
# INFO:tensorflow:loss = 0.00374349, step = 26901 (0.449 sec)
# INFO:tensorflow:global_step/sec: 237.488
# INFO:tensorflow:loss = 0.00442568, step = 27001 (0.423 sec)
# INFO:tensorflow:global_step/sec: 225.976
# INFO:tensorflow:loss = 0.00356017, step = 27101 (0.440 sec)
# INFO:tensorflow:global_step/sec: 223.961
# INFO:tensorflow:loss = 0.00199606, step = 27201 (0.447 sec)
# INFO:tensorflow:global_step/sec: 260
# INFO:tensorflow:loss = 0.00365306, step = 27301 (0.385 sec)
# INFO:tensorflow:global_step/sec: 227.499
# INFO:tensorflow:loss = 0.00308038, step = 27401 (0.439 sec)
# INFO:tensorflow:global_step/sec: 236.735
# INFO:tensorflow:loss = 0.00358454, step = 27501 (0.422 sec)
# INFO:tensorflow:global_step/sec: 260.763
# INFO:tensorflow:loss = 0.0116257, step = 27601 (0.384 sec)
# INFO:tensorflow:global_step/sec: 247.688
# INFO:tensorflow:loss = 0.00308661, step = 27701 (0.404 sec)
# INFO:tensorflow:global_step/sec: 245.361
# INFO:tensorflow:loss = 0.00254382, step = 27801 (0.407 sec)
# INFO:tensorflow:global_step/sec: 237.649
# INFO:tensorflow:loss = 0.00265451, step = 27901 (0.421 sec)
# INFO:tensorflow:global_step/sec: 229.592
# INFO:tensorflow:loss = 0.00329705, step = 28001 (0.436 sec)
# INFO:tensorflow:global_step/sec: 245.837
# INFO:tensorflow:loss = 0.00412588, step = 28101 (0.407 sec)
# INFO:tensorflow:global_step/sec: 264.055
# INFO:tensorflow:loss = 0.00343829, step = 28201 (0.378 sec)
# INFO:tensorflow:global_step/sec: 221.878
# INFO:tensorflow:loss = 0.00364948, step = 28301 (0.451 sec)
# INFO:tensorflow:global_step/sec: 198.804
# INFO:tensorflow:loss = 0.00427465, step = 28401 (0.505 sec)
# INFO:tensorflow:global_step/sec: 211.639
# INFO:tensorflow:loss = 0.00391839, step = 28501 (0.470 sec)
# INFO:tensorflow:global_step/sec: 216.862
# INFO:tensorflow:loss = 0.00329322, step = 28601 (0.461 sec)
# INFO:tensorflow:global_step/sec: 206.905
# INFO:tensorflow:loss = 0.0038536, step = 28701 (0.484 sec)
# INFO:tensorflow:global_step/sec: 219.006
# INFO:tensorflow:loss = 0.00310981, step = 28801 (0.457 sec)
# INFO:tensorflow:global_step/sec: 221.551
# INFO:tensorflow:loss = 0.00459803, step = 28901 (0.451 sec)
# INFO:tensorflow:global_step/sec: 235.765
# INFO:tensorflow:loss = 0.00341488, step = 29001 (0.424 sec)
# INFO:tensorflow:global_step/sec: 176.82
# INFO:tensorflow:loss = 0.00412324, step = 29101 (0.566 sec)
# INFO:tensorflow:global_step/sec: 190.411
# INFO:tensorflow:loss = 0.00301537, step = 29201 (0.525 sec)
# INFO:tensorflow:global_step/sec: 198.038
# INFO:tensorflow:loss = 0.00269459, step = 29301 (0.504 sec)
# INFO:tensorflow:global_step/sec: 183.006
# INFO:tensorflow:loss = 0.00290018, step = 29401 (0.547 sec)
# INFO:tensorflow:global_step/sec: 192.579
# INFO:tensorflow:loss = 0.00314934, step = 29501 (0.518 sec)
# INFO:tensorflow:global_step/sec: 180.67
# INFO:tensorflow:loss = 0.00453879, step = 29601 (0.553 sec)
# INFO:tensorflow:global_step/sec: 189.927
# INFO:tensorflow:loss = 0.00277171, step = 29701 (0.527 sec)
# INFO:tensorflow:global_step/sec: 205.734
# INFO:tensorflow:loss = 0.0034925, step = 29801 (0.486 sec)
# INFO:tensorflow:global_step/sec: 224.79
# INFO:tensorflow:loss = 0.00237523, step = 29901 (0.445 sec)
# INFO:tensorflow:global_step/sec: 234.546
# INFO:tensorflow:loss = 0.00360607, step = 30001 (0.427 sec)
# INFO:tensorflow:global_step/sec: 214.219
# INFO:tensorflow:loss = 0.00299471, step = 30101 (0.466 sec)
# INFO:tensorflow:global_step/sec: 229.409
# INFO:tensorflow:loss = 0.00409553, step = 30201 (0.437 sec)
# INFO:tensorflow:global_step/sec: 231.493
# INFO:tensorflow:loss = 0.0095599, step = 30301 (0.435 sec)
# INFO:tensorflow:global_step/sec: 218.809
# INFO:tensorflow:loss = 0.00466556, step = 30401 (0.454 sec)
# INFO:tensorflow:global_step/sec: 220.837
# INFO:tensorflow:loss = 0.0029476, step = 30501 (0.453 sec)
# INFO:tensorflow:global_step/sec: 178.625
# INFO:tensorflow:loss = 0.0033209, step = 30601 (0.562 sec)
# INFO:tensorflow:global_step/sec: 153.584
# INFO:tensorflow:loss = 0.00278775, step = 30701 (0.650 sec)
# INFO:tensorflow:global_step/sec: 231.259
# INFO:tensorflow:loss = 0.00387074, step = 30801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 222.926
# INFO:tensorflow:loss = 0.00498481, step = 30901 (0.449 sec)
# INFO:tensorflow:global_step/sec: 203.521
# INFO:tensorflow:loss = 0.00339701, step = 31001 (0.491 sec)
# INFO:tensorflow:global_step/sec: 214.485
# INFO:tensorflow:loss = 0.00249151, step = 31101 (0.466 sec)
# INFO:tensorflow:global_step/sec: 228.402
# INFO:tensorflow:loss = 0.00319194, step = 31201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 195.784
# INFO:tensorflow:loss = 0.00383252, step = 31301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 234.249
# INFO:tensorflow:loss = 0.0028811, step = 31401 (0.427 sec)
# INFO:tensorflow:global_step/sec: 225.802
# INFO:tensorflow:loss = 0.00342082, step = 31501 (0.446 sec)
# INFO:tensorflow:global_step/sec: 224.78
# INFO:tensorflow:loss = 0.00335213, step = 31601 (0.443 sec)
# INFO:tensorflow:global_step/sec: 247.362
# INFO:tensorflow:loss = 0.00247988, step = 31701 (0.406 sec)
# INFO:tensorflow:global_step/sec: 244.911
# INFO:tensorflow:loss = 0.00487128, step = 31801 (0.406 sec)
# INFO:tensorflow:global_step/sec: 194.968
# INFO:tensorflow:loss = 0.00240592, step = 31901 (0.513 sec)
# INFO:tensorflow:global_step/sec: 207.26
# INFO:tensorflow:loss = 0.00405458, step = 32001 (0.486 sec)
# INFO:tensorflow:global_step/sec: 199.057
# INFO:tensorflow:loss = 0.00231365, step = 32101 (0.500 sec)
# INFO:tensorflow:global_step/sec: 219.909
# INFO:tensorflow:loss = 0.00302362, step = 32201 (0.455 sec)
# INFO:tensorflow:global_step/sec: 214.666
# INFO:tensorflow:loss = 0.00400401, step = 32301 (0.464 sec)
# INFO:tensorflow:global_step/sec: 207.723
# INFO:tensorflow:loss = 0.00476736, step = 32401 (0.482 sec)
# INFO:tensorflow:global_step/sec: 200.926
# INFO:tensorflow:loss = 0.00360928, step = 32501 (0.497 sec)
# INFO:tensorflow:global_step/sec: 240.644
# INFO:tensorflow:loss = 0.0022582, step = 32601 (0.418 sec)
# INFO:tensorflow:global_step/sec: 247.909
# INFO:tensorflow:loss = 0.00332611, step = 32701 (0.401 sec)
# INFO:tensorflow:global_step/sec: 218.259
# INFO:tensorflow:loss = 0.0025689, step = 32801 (0.460 sec)
# INFO:tensorflow:global_step/sec: 229.797
# INFO:tensorflow:loss = 0.00342745, step = 32901 (0.436 sec)
# INFO:tensorflow:global_step/sec: 235.516
# INFO:tensorflow:loss = 0.00517979, step = 33001 (0.423 sec)
# INFO:tensorflow:global_step/sec: 245.367
# INFO:tensorflow:loss = 0.00388015, step = 33101 (0.406 sec)
# INFO:tensorflow:global_step/sec: 236.706
# INFO:tensorflow:loss = 0.0038638, step = 33201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 233.062
# INFO:tensorflow:loss = 0.00389884, step = 33301 (0.429 sec)
# INFO:tensorflow:global_step/sec: 207.541
# INFO:tensorflow:loss = 0.00347748, step = 33401 (0.481 sec)
# INFO:tensorflow:global_step/sec: 216.62
# INFO:tensorflow:loss = 0.00372043, step = 33501 (0.462 sec)
# INFO:tensorflow:global_step/sec: 190.39
# INFO:tensorflow:loss = 0.00406682, step = 33601 (0.525 sec)
# INFO:tensorflow:global_step/sec: 254.781
# INFO:tensorflow:loss = 0.00394359, step = 33701 (0.393 sec)
# INFO:tensorflow:global_step/sec: 280.449
# INFO:tensorflow:loss = 0.00379336, step = 33801 (0.357 sec)
# INFO:tensorflow:global_step/sec: 249.16
# INFO:tensorflow:loss = 0.00437404, step = 33901 (0.402 sec)
# INFO:tensorflow:global_step/sec: 220.241
# INFO:tensorflow:loss = 0.00217647, step = 34001 (0.456 sec)
# INFO:tensorflow:global_step/sec: 239.332
# INFO:tensorflow:loss = 0.00220384, step = 34101 (0.418 sec)
# INFO:tensorflow:global_step/sec: 253.673
# INFO:tensorflow:loss = 0.00295977, step = 34201 (0.392 sec)
# INFO:tensorflow:global_step/sec: 247.659
# INFO:tensorflow:loss = 0.00322305, step = 34301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 227.176
# INFO:tensorflow:loss = 0.0027355, step = 34401 (0.440 sec)
# INFO:tensorflow:global_step/sec: 251.9
# INFO:tensorflow:loss = 0.00317922, step = 34501 (0.396 sec)
# INFO:tensorflow:global_step/sec: 219.487
# INFO:tensorflow:loss = 0.00351057, step = 34601 (0.456 sec)
# INFO:tensorflow:global_step/sec: 256.47
# INFO:tensorflow:loss = 0.00347146, step = 34701 (0.390 sec)
# INFO:tensorflow:global_step/sec: 221.738
# INFO:tensorflow:loss = 0.00392369, step = 34801 (0.455 sec)
# INFO:tensorflow:global_step/sec: 204.801
# INFO:tensorflow:loss = 0.00460916, step = 34901 (0.483 sec)
# INFO:tensorflow:global_step/sec: 237.736
# INFO:tensorflow:loss = 0.00318859, step = 35001 (0.421 sec)
# INFO:tensorflow:global_step/sec: 214.701
# INFO:tensorflow:loss = 0.00337054, step = 35101 (0.466 sec)
# INFO:tensorflow:global_step/sec: 258.111
# INFO:tensorflow:loss = 0.00284364, step = 35201 (0.388 sec)
# INFO:tensorflow:global_step/sec: 249.64
# INFO:tensorflow:loss = 0.00348925, step = 35301 (0.400 sec)
# INFO:tensorflow:global_step/sec: 278.897
# INFO:tensorflow:loss = 0.00680694, step = 35401 (0.358 sec)
# INFO:tensorflow:global_step/sec: 226.067
# INFO:tensorflow:loss = 0.00271256, step = 35501 (0.444 sec)
# INFO:tensorflow:global_step/sec: 239.542
# INFO:tensorflow:loss = 0.00373862, step = 35601 (0.416 sec)
# INFO:tensorflow:global_step/sec: 242.252
# INFO:tensorflow:loss = 0.00226442, step = 35701 (0.412 sec)
# INFO:tensorflow:global_step/sec: 227.751
# INFO:tensorflow:loss = 0.00493144, step = 35801 (0.439 sec)
# INFO:tensorflow:global_step/sec: 204.316
# INFO:tensorflow:loss = 0.0041008, step = 35901 (0.489 sec)
# INFO:tensorflow:global_step/sec: 197.454
# INFO:tensorflow:loss = 0.00425032, step = 36001 (0.507 sec)
# INFO:tensorflow:global_step/sec: 241.091
# INFO:tensorflow:loss = 0.00433684, step = 36101 (0.414 sec)
# INFO:tensorflow:global_step/sec: 206.701
# INFO:tensorflow:loss = 0.00485342, step = 36201 (0.484 sec)
# INFO:tensorflow:global_step/sec: 236.47
# INFO:tensorflow:loss = 0.00309167, step = 36301 (0.425 sec)
# INFO:tensorflow:global_step/sec: 210.171
# INFO:tensorflow:loss = 0.00385482, step = 36401 (0.474 sec)
# INFO:tensorflow:global_step/sec: 188.264
# INFO:tensorflow:loss = 0.00390168, step = 36501 (0.531 sec)
# INFO:tensorflow:global_step/sec: 183.547
# INFO:tensorflow:loss = 0.00449906, step = 36601 (0.545 sec)
# INFO:tensorflow:global_step/sec: 222.576
# INFO:tensorflow:loss = 0.00228941, step = 36701 (0.449 sec)
# INFO:tensorflow:global_step/sec: 251.042
# INFO:tensorflow:loss = 0.00406771, step = 36801 (0.398 sec)
# INFO:tensorflow:global_step/sec: 230.13
# INFO:tensorflow:loss = 0.00361878, step = 36901 (0.435 sec)
# INFO:tensorflow:global_step/sec: 223.81
# INFO:tensorflow:loss = 0.0040963, step = 37001 (0.447 sec)
# INFO:tensorflow:global_step/sec: 216.324
# INFO:tensorflow:loss = 0.00283935, step = 37101 (0.462 sec)
# INFO:tensorflow:global_step/sec: 220.622
# INFO:tensorflow:loss = 0.00347281, step = 37201 (0.453 sec)
# INFO:tensorflow:global_step/sec: 187.168
# INFO:tensorflow:loss = 0.00278024, step = 37301 (0.535 sec)
# INFO:tensorflow:global_step/sec: 222.726
# INFO:tensorflow:loss = 0.00250926, step = 37401 (0.449 sec)
# INFO:tensorflow:global_step/sec: 209.294
# INFO:tensorflow:loss = 0.00412201, step = 37501 (0.477 sec)
# INFO:tensorflow:global_step/sec: 258.602
# INFO:tensorflow:loss = 0.00424434, step = 37601 (0.387 sec)
# INFO:tensorflow:global_step/sec: 255.544
# INFO:tensorflow:loss = 0.00237582, step = 37701 (0.392 sec)
# INFO:tensorflow:global_step/sec: 256.035
# INFO:tensorflow:loss = 0.00233164, step = 37801 (0.390 sec)
# INFO:tensorflow:global_step/sec: 240.199
# INFO:tensorflow:loss = 0.00361661, step = 37901 (0.417 sec)
# INFO:tensorflow:global_step/sec: 220.607
# INFO:tensorflow:loss = 0.00316936, step = 38001 (0.453 sec)
# INFO:tensorflow:global_step/sec: 239.981
# INFO:tensorflow:loss = 0.00246614, step = 38101 (0.416 sec)
# INFO:tensorflow:global_step/sec: 228.725
# INFO:tensorflow:loss = 0.00386319, step = 38201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 238.276
# INFO:tensorflow:loss = 0.00234236, step = 38301 (0.419 sec)
# INFO:tensorflow:global_step/sec: 217.292
# INFO:tensorflow:loss = 0.00887863, step = 38401 (0.460 sec)
# INFO:tensorflow:global_step/sec: 203.224
# INFO:tensorflow:loss = 0.00220047, step = 38501 (0.492 sec)
# INFO:tensorflow:global_step/sec: 228.684
# INFO:tensorflow:loss = 0.00383987, step = 38601 (0.439 sec)
# INFO:tensorflow:global_step/sec: 228.819
# INFO:tensorflow:loss = 0.00229658, step = 38701 (0.436 sec)
# INFO:tensorflow:global_step/sec: 188.171
# INFO:tensorflow:loss = 0.0045674, step = 38801 (0.532 sec)
# INFO:tensorflow:global_step/sec: 250.143
# INFO:tensorflow:loss = 0.00336448, step = 38901 (0.399 sec)
# INFO:tensorflow:global_step/sec: 209.845
# INFO:tensorflow:loss = 0.00557695, step = 39001 (0.477 sec)
# INFO:tensorflow:global_step/sec: 231.693
# INFO:tensorflow:loss = 0.0032439, step = 39101 (0.431 sec)
# INFO:tensorflow:global_step/sec: 236.943
# INFO:tensorflow:loss = 0.00338202, step = 39201 (0.422 sec)
# INFO:tensorflow:global_step/sec: 269.01
# INFO:tensorflow:loss = 0.00491184, step = 39301 (0.372 sec)
# INFO:tensorflow:global_step/sec: 240.576
# INFO:tensorflow:loss = 0.00325095, step = 39401 (0.416 sec)
# INFO:tensorflow:global_step/sec: 232.155
# INFO:tensorflow:loss = 0.00432403, step = 39501 (0.431 sec)
# INFO:tensorflow:global_step/sec: 239.103
# INFO:tensorflow:loss = 0.0042522, step = 39601 (0.419 sec)
# INFO:tensorflow:global_step/sec: 247.455
# INFO:tensorflow:loss = 0.00461168, step = 39701 (0.403 sec)
# INFO:tensorflow:global_step/sec: 231.348
# INFO:tensorflow:loss = 0.004185, step = 39801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 242.615
# INFO:tensorflow:loss = 0.00389982, step = 39901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 235.497
# INFO:tensorflow:loss = 0.00362931, step = 40001 (0.425 sec)
# INFO:tensorflow:global_step/sec: 213.776
# INFO:tensorflow:loss = 0.00268819, step = 40101 (0.469 sec)
# INFO:tensorflow:global_step/sec: 227.714
# INFO:tensorflow:loss = 0.00299774, step = 40201 (0.439 sec)
# INFO:tensorflow:global_step/sec: 232.068
# INFO:tensorflow:loss = 0.0025458, step = 40301 (0.431 sec)
# INFO:tensorflow:global_step/sec: 229.42
# INFO:tensorflow:loss = 0.00385265, step = 40401 (0.437 sec)
# INFO:tensorflow:global_step/sec: 205.561
# INFO:tensorflow:loss = 0.00303747, step = 40501 (0.485 sec)
# INFO:tensorflow:global_step/sec: 224.89
# INFO:tensorflow:loss = 0.00411958, step = 40601 (0.445 sec)
# INFO:tensorflow:global_step/sec: 196.274
# INFO:tensorflow:loss = 0.00277713, step = 40701 (0.510 sec)
# INFO:tensorflow:global_step/sec: 228.662
# INFO:tensorflow:loss = 0.00323826, step = 40801 (0.437 sec)
# INFO:tensorflow:global_step/sec: 222.243
# INFO:tensorflow:loss = 0.00420899, step = 40901 (0.450 sec)
# INFO:tensorflow:global_step/sec: 227.552
# INFO:tensorflow:loss = 0.002575, step = 41001 (0.439 sec)
# INFO:tensorflow:global_step/sec: 190.48
# INFO:tensorflow:loss = 0.00305218, step = 41101 (0.525 sec)
# INFO:tensorflow:global_step/sec: 226.154
# INFO:tensorflow:loss = 0.00299083, step = 41201 (0.442 sec)
# INFO:tensorflow:global_step/sec: 190.547
# INFO:tensorflow:loss = 0.00335152, step = 41301 (0.525 sec)
# INFO:tensorflow:global_step/sec: 221.574
# INFO:tensorflow:loss = 0.0030129, step = 41401 (0.452 sec)
# INFO:tensorflow:global_step/sec: 233.349
# INFO:tensorflow:loss = 0.00359678, step = 41501 (0.428 sec)
# INFO:tensorflow:global_step/sec: 244.264
# INFO:tensorflow:loss = 0.00317311, step = 41601 (0.409 sec)
# INFO:tensorflow:global_step/sec: 250.901
# INFO:tensorflow:loss = 0.00326665, step = 41701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 226.861
# INFO:tensorflow:loss = 0.0036336, step = 41801 (0.441 sec)
# INFO:tensorflow:global_step/sec: 238.136
# INFO:tensorflow:loss = 0.00328856, step = 41901 (0.420 sec)
# INFO:tensorflow:global_step/sec: 210.405
# INFO:tensorflow:loss = 0.00283251, step = 42001 (0.476 sec)
# INFO:tensorflow:global_step/sec: 247.576
# INFO:tensorflow:loss = 0.00340318, step = 42101 (0.404 sec)
# INFO:tensorflow:global_step/sec: 255.709
# INFO:tensorflow:loss = 0.0028192, step = 42201 (0.391 sec)
# INFO:tensorflow:global_step/sec: 249.15
# INFO:tensorflow:loss = 0.00376339, step = 42301 (0.401 sec)
# INFO:tensorflow:global_step/sec: 236.884
# INFO:tensorflow:loss = 0.00320142, step = 42401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 258.523
# INFO:tensorflow:loss = 0.00363433, step = 42501 (0.387 sec)
# INFO:tensorflow:global_step/sec: 192.609
# INFO:tensorflow:loss = 0.00315728, step = 42601 (0.519 sec)
# INFO:tensorflow:global_step/sec: 245.415
# INFO:tensorflow:loss = 0.00260905, step = 42701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 227.904
# INFO:tensorflow:loss = 0.003448, step = 42801 (0.439 sec)
# INFO:tensorflow:global_step/sec: 230.288
# INFO:tensorflow:loss = 0.00288556, step = 42901 (0.435 sec)
# INFO:tensorflow:global_step/sec: 251.323
# INFO:tensorflow:loss = 0.00398542, step = 43001 (0.398 sec)
# INFO:tensorflow:global_step/sec: 203.349
# INFO:tensorflow:loss = 0.00360847, step = 43101 (0.493 sec)
# INFO:tensorflow:global_step/sec: 225.49
# INFO:tensorflow:loss = 0.0034407, step = 43201 (0.441 sec)
# INFO:tensorflow:global_step/sec: 230.886
# INFO:tensorflow:loss = 0.00384958, step = 43301 (0.433 sec)
# INFO:tensorflow:global_step/sec: 215.848
# INFO:tensorflow:loss = 0.00238832, step = 43401 (0.463 sec)
# INFO:tensorflow:global_step/sec: 215.656
# INFO:tensorflow:loss = 0.00279855, step = 43501 (0.464 sec)
# INFO:tensorflow:global_step/sec: 217.581
# INFO:tensorflow:loss = 0.00325772, step = 43601 (0.459 sec)
# INFO:tensorflow:global_step/sec: 235.509
# INFO:tensorflow:loss = 0.00289866, step = 43701 (0.426 sec)
# INFO:tensorflow:global_step/sec: 272.498
# INFO:tensorflow:loss = 0.0039969, step = 43801 (0.365 sec)
# INFO:tensorflow:global_step/sec: 216.578
# INFO:tensorflow:loss = 0.00285056, step = 43901 (0.462 sec)
# INFO:tensorflow:global_step/sec: 221.045
# INFO:tensorflow:loss = 0.00281119, step = 44001 (0.454 sec)
# INFO:tensorflow:global_step/sec: 249.743
# INFO:tensorflow:loss = 0.00703238, step = 44101 (0.399 sec)
# INFO:tensorflow:global_step/sec: 238.836
# INFO:tensorflow:loss = 0.00323507, step = 44201 (0.419 sec)
# INFO:tensorflow:global_step/sec: 207.507
# INFO:tensorflow:loss = 0.00300456, step = 44301 (0.481 sec)
# INFO:tensorflow:global_step/sec: 227.124
# INFO:tensorflow:loss = 0.00322602, step = 44401 (0.440 sec)
# INFO:tensorflow:global_step/sec: 258.4
# INFO:tensorflow:loss = 0.00268067, step = 44501 (0.387 sec)
# INFO:tensorflow:global_step/sec: 232.39
# INFO:tensorflow:loss = 0.00280618, step = 44601 (0.430 sec)
# INFO:tensorflow:global_step/sec: 247.056
# ...
# INFO:tensorflow:loss = 0.00403261, step = 136101 (0.444 sec)
# INFO:tensorflow:global_step/sec: 258.075
# INFO:tensorflow:loss = 0.00328539, step = 136201 (0.388 sec)
# INFO:tensorflow:global_step/sec: 220.155
# INFO:tensorflow:loss = 0.00236375, step = 136301 (0.459 sec)
# INFO:tensorflow:global_step/sec: 237.574
# INFO:tensorflow:loss = 0.00277315, step = 136401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 217.92
# INFO:tensorflow:loss = 0.00295385, step = 136501 (0.459 sec)
# INFO:tensorflow:global_step/sec: 215.99
# INFO:tensorflow:loss = 0.00252096, step = 136601 (0.463 sec)
# INFO:tensorflow:global_step/sec: 192.2
# INFO:tensorflow:loss = 0.0030164, step = 136701 (0.520 sec)
# INFO:tensorflow:global_step/sec: 233.955
# INFO:tensorflow:loss = 0.00278286, step = 136801 (0.427 sec)
# INFO:tensorflow:global_step/sec: 240.05
# INFO:tensorflow:loss = 0.00236213, step = 136901 (0.417 sec)
# INFO:tensorflow:global_step/sec: 240.629
# INFO:tensorflow:loss = 0.00261994, step = 137001 (0.416 sec)
# INFO:tensorflow:global_step/sec: 216.089
# INFO:tensorflow:loss = 0.00222777, step = 137101 (0.463 sec)
# INFO:tensorflow:global_step/sec: 263.425
# INFO:tensorflow:loss = 0.00321527, step = 137201 (0.379 sec)
# INFO:tensorflow:global_step/sec: 242.652
# INFO:tensorflow:loss = 0.00172338, step = 137301 (0.412 sec)
# INFO:tensorflow:global_step/sec: 256.546
# INFO:tensorflow:loss = 0.00328602, step = 137401 (0.391 sec)
# INFO:tensorflow:global_step/sec: 224.075
# INFO:tensorflow:loss = 0.00245451, step = 137501 (0.448 sec)
# INFO:tensorflow:global_step/sec: 216.601
# INFO:tensorflow:loss = 0.00297734, step = 137601 (0.458 sec)
# INFO:tensorflow:global_step/sec: 189.703
# INFO:tensorflow:loss = 0.00308546, step = 137701 (0.534 sec)
# INFO:tensorflow:global_step/sec: 243.109
# INFO:tensorflow:loss = 0.00196474, step = 137801 (0.405 sec)
# INFO:tensorflow:global_step/sec: 238.728
# INFO:tensorflow:loss = 0.00297214, step = 137901 (0.418 sec)
# INFO:tensorflow:global_step/sec: 223.737
# INFO:tensorflow:loss = 0.00321488, step = 138001 (0.447 sec)
# INFO:tensorflow:global_step/sec: 231.412
# INFO:tensorflow:loss = 0.00271328, step = 138101 (0.433 sec)
# INFO:tensorflow:global_step/sec: 233.962
# INFO:tensorflow:loss = 0.00275612, step = 138201 (0.427 sec)
# INFO:tensorflow:global_step/sec: 236.718
# INFO:tensorflow:loss = 0.00528513, step = 138301 (0.423 sec)
# INFO:tensorflow:global_step/sec: 247.966
# INFO:tensorflow:loss = 0.00354485, step = 138401 (0.403 sec)
# INFO:tensorflow:global_step/sec: 231.197
# INFO:tensorflow:loss = 0.00187979, step = 138501 (0.433 sec)
# INFO:tensorflow:global_step/sec: 239.644
# INFO:tensorflow:loss = 0.00341472, step = 138601 (0.417 sec)
# INFO:tensorflow:global_step/sec: 215.273
# INFO:tensorflow:loss = 0.00245955, step = 138701 (0.465 sec)
# INFO:tensorflow:global_step/sec: 231.051
# INFO:tensorflow:loss = 0.00246412, step = 138801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 247.406
# INFO:tensorflow:loss = 0.00285617, step = 138901 (0.404 sec)
# INFO:tensorflow:global_step/sec: 257.558
# INFO:tensorflow:loss = 0.00261313, step = 139001 (0.389 sec)
# INFO:tensorflow:global_step/sec: 258.556
# INFO:tensorflow:loss = 0.00339581, step = 139101 (0.387 sec)
# INFO:tensorflow:global_step/sec: 274.625
# INFO:tensorflow:loss = 0.00319029, step = 139201 (0.365 sec)
# INFO:tensorflow:global_step/sec: 242.686
# INFO:tensorflow:loss = 0.00205004, step = 139301 (0.411 sec)
# INFO:tensorflow:global_step/sec: 241.88
# INFO:tensorflow:loss = 0.00197845, step = 139401 (0.413 sec)
# INFO:tensorflow:global_step/sec: 216.761
# INFO:tensorflow:loss = 0.00169227, step = 139501 (0.462 sec)
# INFO:tensorflow:global_step/sec: 214.893
# INFO:tensorflow:loss = 0.00350851, step = 139601 (0.465 sec)
# INFO:tensorflow:global_step/sec: 226.856
# INFO:tensorflow:loss = 0.00189053, step = 139701 (0.440 sec)
# INFO:tensorflow:global_step/sec: 230.542
# INFO:tensorflow:loss = 0.00437909, step = 139801 (0.434 sec)
# INFO:tensorflow:global_step/sec: 224.041
# INFO:tensorflow:loss = 0.00227926, step = 139901 (0.446 sec)
# INFO:tensorflow:global_step/sec: 267.36
# INFO:tensorflow:loss = 0.00262815, step = 140001 (0.374 sec)
# INFO:tensorflow:global_step/sec: 247.495
# INFO:tensorflow:loss = 0.002614, step = 140101 (0.404 sec)
# INFO:tensorflow:global_step/sec: 237.37
# INFO:tensorflow:loss = 0.00232262, step = 140201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 271.497
# INFO:tensorflow:loss = 0.00348085, step = 140301 (0.366 sec)
# INFO:tensorflow:global_step/sec: 204.568
# INFO:tensorflow:loss = 0.00201572, step = 140401 (0.489 sec)
# INFO:tensorflow:global_step/sec: 235.204
# INFO:tensorflow:loss = 0.00279627, step = 140501 (0.427 sec)
# INFO:tensorflow:global_step/sec: 231.388
# INFO:tensorflow:loss = 0.00249074, step = 140601 (0.431 sec)
# INFO:tensorflow:global_step/sec: 224.92
# INFO:tensorflow:loss = 0.00254312, step = 140701 (0.444 sec)
# INFO:tensorflow:global_step/sec: 204.721
# INFO:tensorflow:loss = 0.00315317, step = 140801 (0.490 sec)
# INFO:tensorflow:global_step/sec: 235.083
# INFO:tensorflow:loss = 0.00326378, step = 140901 (0.424 sec)
# INFO:tensorflow:global_step/sec: 214.501
# INFO:tensorflow:loss = 0.00247377, step = 141001 (0.465 sec)
# INFO:tensorflow:global_step/sec: 213.195
# INFO:tensorflow:loss = 0.00300644, step = 141101 (0.469 sec)
# INFO:tensorflow:global_step/sec: 215.131
# INFO:tensorflow:loss = 0.00256286, step = 141201 (0.465 sec)
# INFO:tensorflow:global_step/sec: 218.398
# INFO:tensorflow:loss = 0.00263521, step = 141301 (0.460 sec)
# INFO:tensorflow:global_step/sec: 217.717
# INFO:tensorflow:loss = 0.00257006, step = 141401 (0.457 sec)
# INFO:tensorflow:global_step/sec: 251.462
# INFO:tensorflow:loss = 0.00235097, step = 141501 (0.397 sec)
# INFO:tensorflow:global_step/sec: 254.026
# INFO:tensorflow:loss = 0.00229017, step = 141601 (0.394 sec)
# INFO:tensorflow:global_step/sec: 227.831
# INFO:tensorflow:loss = 0.00218554, step = 141701 (0.439 sec)
# INFO:tensorflow:global_step/sec: 228.392
# INFO:tensorflow:loss = 0.00216208, step = 141801 (0.438 sec)
# INFO:tensorflow:global_step/sec: 198.343
# INFO:tensorflow:loss = 0.00267366, step = 141901 (0.505 sec)
# INFO:tensorflow:global_step/sec: 186.699
# INFO:tensorflow:loss = 0.00258739, step = 142001 (0.535 sec)
# INFO:tensorflow:global_step/sec: 222.96
# INFO:tensorflow:loss = 0.00247054, step = 142101 (0.449 sec)
# INFO:tensorflow:global_step/sec: 241.267
# INFO:tensorflow:loss = 0.00282045, step = 142201 (0.415 sec)
# INFO:tensorflow:global_step/sec: 232.404
# INFO:tensorflow:loss = 0.00262976, step = 142301 (0.430 sec)
# INFO:tensorflow:global_step/sec: 257.38
# INFO:tensorflow:loss = 0.00255584, step = 142401 (0.390 sec)
# INFO:tensorflow:global_step/sec: 218.054
# INFO:tensorflow:loss = 0.00213472, step = 142501 (0.458 sec)
# INFO:tensorflow:global_step/sec: 219.013
# INFO:tensorflow:loss = 0.0027346, step = 142601 (0.456 sec)
# INFO:tensorflow:global_step/sec: 220.988
# INFO:tensorflow:loss = 0.00213538, step = 142701 (0.452 sec)
# INFO:tensorflow:global_step/sec: 253.299
# INFO:tensorflow:loss = 0.00344008, step = 142801 (0.395 sec)
# INFO:tensorflow:global_step/sec: 252.969
# INFO:tensorflow:loss = 0.00215341, step = 142901 (0.398 sec)
# INFO:tensorflow:global_step/sec: 248.486
# INFO:tensorflow:loss = 0.00258432, step = 143001 (0.400 sec)
# INFO:tensorflow:global_step/sec: 240.699
# INFO:tensorflow:loss = 0.00313062, step = 143101 (0.417 sec)
# INFO:tensorflow:global_step/sec: 223.845
# INFO:tensorflow:loss = 0.00202465, step = 143201 (0.445 sec)
# INFO:tensorflow:global_step/sec: 240.04
# INFO:tensorflow:loss = 0.00234352, step = 143301 (0.417 sec)
# INFO:tensorflow:global_step/sec: 184.698
# INFO:tensorflow:loss = 0.0032362, step = 143401 (0.541 sec)
# INFO:tensorflow:global_step/sec: 255.286
# INFO:tensorflow:loss = 0.00190047, step = 143501 (0.393 sec)
# INFO:tensorflow:global_step/sec: 250.522
# INFO:tensorflow:loss = 0.0027754, step = 143601 (0.398 sec)
# INFO:tensorflow:global_step/sec: 242.662
# INFO:tensorflow:loss = 0.00326621, step = 143701 (0.412 sec)
# INFO:tensorflow:global_step/sec: 242.338
# INFO:tensorflow:loss = 0.00222779, step = 143801 (0.413 sec)
# INFO:tensorflow:global_step/sec: 187.564
# INFO:tensorflow:loss = 0.0022966, step = 143901 (0.533 sec)
# INFO:tensorflow:global_step/sec: 227.886
# INFO:tensorflow:loss = 0.00260571, step = 144001 (0.440 sec)
# INFO:tensorflow:global_step/sec: 236.715
# INFO:tensorflow:loss = 0.00268687, step = 144101 (0.421 sec)
# INFO:tensorflow:global_step/sec: 235.313
# INFO:tensorflow:loss = 0.00253284, step = 144201 (0.425 sec)
# INFO:tensorflow:global_step/sec: 247.346
# INFO:tensorflow:loss = 0.00301579, step = 144301 (0.404 sec)
# INFO:tensorflow:global_step/sec: 231.167
# INFO:tensorflow:loss = 0.00244441, step = 144401 (0.433 sec)
# INFO:tensorflow:global_step/sec: 235.132
# INFO:tensorflow:loss = 0.00278139, step = 144501 (0.425 sec)
# INFO:tensorflow:global_step/sec: 245.766
# INFO:tensorflow:loss = 0.00493718, step = 144601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 198.439
# INFO:tensorflow:loss = 0.00264425, step = 144701 (0.505 sec)
# INFO:tensorflow:global_step/sec: 169.771
# INFO:tensorflow:loss = 0.00276217, step = 144801 (0.588 sec)
# INFO:tensorflow:global_step/sec: 242.924
# INFO:tensorflow:loss = 0.00206555, step = 144901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 236.767
# INFO:tensorflow:loss = 0.0020766, step = 145001 (0.423 sec)
# INFO:tensorflow:global_step/sec: 249.263
# INFO:tensorflow:loss = 0.00290038, step = 145101 (0.400 sec)
# INFO:tensorflow:global_step/sec: 249.808
# INFO:tensorflow:loss = 0.00300465, step = 145201 (0.400 sec)
# INFO:tensorflow:global_step/sec: 260.491
# INFO:tensorflow:loss = 0.00150123, step = 145301 (0.384 sec)
# INFO:tensorflow:global_step/sec: 234.201
# INFO:tensorflow:loss = 0.00297173, step = 145401 (0.429 sec)
# INFO:tensorflow:global_step/sec: 236.663
# INFO:tensorflow:loss = 0.00393468, step = 145501 (0.420 sec)
# INFO:tensorflow:global_step/sec: 248.416
# INFO:tensorflow:loss = 0.00282369, step = 145601 (0.403 sec)
# INFO:tensorflow:global_step/sec: 231.963
# INFO:tensorflow:loss = 0.0026244, step = 145701 (0.431 sec)
# INFO:tensorflow:global_step/sec: 204.527
# INFO:tensorflow:loss = 0.00363937, step = 145801 (0.489 sec)
# INFO:tensorflow:global_step/sec: 241.12
# INFO:tensorflow:loss = 0.00242441, step = 145901 (0.416 sec)
# INFO:tensorflow:global_step/sec: 242.951
# INFO:tensorflow:loss = 0.00286642, step = 146001 (0.413 sec)
# INFO:tensorflow:global_step/sec: 234.114
# INFO:tensorflow:loss = 0.00344123, step = 146101 (0.426 sec)
# INFO:tensorflow:global_step/sec: 237.62
# INFO:tensorflow:loss = 0.00276428, step = 146201 (0.420 sec)
# INFO:tensorflow:global_step/sec: 249.814
# INFO:tensorflow:loss = 0.00275693, step = 146301 (0.400 sec)
# INFO:tensorflow:global_step/sec: 215.016
# INFO:tensorflow:loss = 0.00288719, step = 146401 (0.465 sec)
# INFO:tensorflow:global_step/sec: 232.084
# INFO:tensorflow:loss = 0.00252763, step = 146501 (0.433 sec)
# INFO:tensorflow:global_step/sec: 244.654
# INFO:tensorflow:loss = 0.00182727, step = 146601 (0.408 sec)
# INFO:tensorflow:global_step/sec: 252.396
# INFO:tensorflow:loss = 0.00225366, step = 146701 (0.396 sec)
# INFO:tensorflow:global_step/sec: 246.957
# INFO:tensorflow:loss = 0.00158623, step = 146801 (0.405 sec)
# INFO:tensorflow:global_step/sec: 236.731
# INFO:tensorflow:loss = 0.0025654, step = 146901 (0.422 sec)
# INFO:tensorflow:global_step/sec: 247.834
# INFO:tensorflow:loss = 0.00279862, step = 147001 (0.404 sec)
# INFO:tensorflow:global_step/sec: 274.156
# INFO:tensorflow:loss = 0.00199766, step = 147101 (0.365 sec)
# INFO:tensorflow:global_step/sec: 226.545
# INFO:tensorflow:loss = 0.00242039, step = 147201 (0.442 sec)
# INFO:tensorflow:global_step/sec: 231.263
# INFO:tensorflow:loss = 0.00219447, step = 147301 (0.432 sec)
# INFO:tensorflow:global_step/sec: 206.922
# INFO:tensorflow:loss = 0.00238341, step = 147401 (0.484 sec)
# INFO:tensorflow:global_step/sec: 216.993
# INFO:tensorflow:loss = 0.00178358, step = 147501 (0.461 sec)
# INFO:tensorflow:global_step/sec: 243.925
# INFO:tensorflow:loss = 0.00194042, step = 147601 (0.409 sec)
# INFO:tensorflow:global_step/sec: 253.04
# INFO:tensorflow:loss = 0.00217829, step = 147701 (0.395 sec)
# INFO:tensorflow:global_step/sec: 248.742
# INFO:tensorflow:loss = 0.00273747, step = 147801 (0.403 sec)
# INFO:tensorflow:global_step/sec: 175.996
# INFO:tensorflow:loss = 0.00259322, step = 147901 (0.568 sec)
# INFO:tensorflow:global_step/sec: 183.115
# INFO:tensorflow:loss = 0.0023177, step = 148001 (0.548 sec)
# INFO:tensorflow:global_step/sec: 253.536
# INFO:tensorflow:loss = 0.00169817, step = 148101 (0.392 sec)
# INFO:tensorflow:global_step/sec: 242.47
# INFO:tensorflow:loss = 0.0027844, step = 148201 (0.413 sec)
# INFO:tensorflow:global_step/sec: 219.448
# INFO:tensorflow:loss = 0.00330677, step = 148301 (0.455 sec)
# INFO:tensorflow:global_step/sec: 224.712
# INFO:tensorflow:loss = 0.00295732, step = 148401 (0.445 sec)
# INFO:tensorflow:global_step/sec: 253.302
# INFO:tensorflow:loss = 0.00239749, step = 148501 (0.395 sec)
# INFO:tensorflow:global_step/sec: 246.602
# INFO:tensorflow:loss = 0.00211405, step = 148601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 244.194
# INFO:tensorflow:loss = 0.00228397, step = 148701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 246.633
# INFO:tensorflow:loss = 0.00323618, step = 148801 (0.405 sec)
# INFO:tensorflow:global_step/sec: 263.907
# INFO:tensorflow:loss = 0.00231018, step = 148901 (0.379 sec)
# INFO:tensorflow:global_step/sec: 248.948
# INFO:tensorflow:loss = 0.00234098, step = 149001 (0.402 sec)
# INFO:tensorflow:global_step/sec: 243
# INFO:tensorflow:loss = 0.00321461, step = 149101 (0.411 sec)
# INFO:tensorflow:global_step/sec: 258.986
# INFO:tensorflow:loss = 0.0021347, step = 149201 (0.388 sec)
# INFO:tensorflow:global_step/sec: 225.969
# INFO:tensorflow:loss = 0.00254794, step = 149301 (0.442 sec)
# INFO:tensorflow:global_step/sec: 248.234
# INFO:tensorflow:loss = 0.0026388, step = 149401 (0.401 sec)
# INFO:tensorflow:global_step/sec: 222.544
# INFO:tensorflow:loss = 0.00230804, step = 149501 (0.452 sec)
# INFO:tensorflow:global_step/sec: 246.521
# INFO:tensorflow:loss = 0.00211184, step = 149601 (0.404 sec)
# INFO:tensorflow:global_step/sec: 238.117
# INFO:tensorflow:loss = 0.00346935, step = 149701 (0.421 sec)
# INFO:tensorflow:global_step/sec: 230.864
# INFO:tensorflow:loss = 0.00267776, step = 149801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 224.979
# INFO:tensorflow:loss = 0.00235413, step = 149901 (0.444 sec)
# INFO:tensorflow:Saving checkpoints for 150000 into ./AR3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00070631.
# WARNING:tensorflow:From <ipython-input-38-9ac2a927eaa3>:11: calling predict_scores (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:744: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:744: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from ./AR3/model.ckpt-150000
# Root mean square Error: 0.067

# %% [markdown]
# Comment: We use DNN Regression Model with 2 layers: 1 input with 100 nodes, and 1 output with 100 nodes, and train our neural networks using the train set X obtained from a random cut to our original dataset,  and then measure its accuracy with RMSE using the test set X. We save our model into the same folder as our Python code with the file name "SP". In this case, the RMSE of DNN Regression is much higher than that of RF or Linear Regression Model

# %%
x = np.array([0.56,0.2, 18,0, 0, 0, 0, 0, 0, 1])
feature_column1 = learn.infer_real_valued_columns_from_input(x)

y = np.array([[0.8515, 0.1485, 0.15981, 0.1328, 0.46875*24, 0, 1, 0, 0, 0, 0, 0]])
new_regressor = learn.DNNRegressor(feature_columns = feature_column1, hidden_units= [100,100], model_dir = './AR3')
new_regressor.predict_scores(y, as_iterable = False)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9438ee4450>, '_model_dir': './AR3', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': None, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_evaluation_master': '', '_master': ''}
# WARNING:tensorflow:From <ipython-input-49-ba227ded3154>:6: calling predict_scores (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:744: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:744: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from ./AR3/model.ckpt-150000
# array([ 0.36590445], dtype=float32)

# %% [markdown]
# Comment: We load our saved neural network model, and then use it to make prediction with new input. Note that the dimension of the *VECTOR* input always *EQUALS* to (number of columns of train_X x 1). The prediction here is sometimes more accurate than that of RF (although they are pretty close), but most of the time it is worse than RF. Furthermore, RF is way better than Linear Regression model for this particular problem when testing with real-world inputs (based on trends and how accurate the predicted value is compared to actual).

# %% [markdown]
# # Correlation testing between acceptance rate, online drivers and percent change in online drivers

# %%
corr_matrix = Ha_Noi.corr()
corr_matrix["accept_rate"].sort_values(ascending=False)

# %matplotlib inline
# import matplotlib.pyplot as plt
# df2.hist(bins = 50, figsize = (15, 15))
# Out:
# accept_rate                                      1.000000
# accept_rate_timeT                                0.683009
# online_drivers (no data on day 13 - 09:20:00)    0.140001
# Percentchange_onlinedrivers                      0.082624
# wd3                                              0.068297
# wd2                                              0.048107
# wd4                                              0.039887
# wd7                                              0.009160
# wd5                                             -0.023075
# Pricing_timeT                                   -0.028831
# DriverBusyRate                                  -0.030489
# wd6                                             -0.048887
# Pricing                                         -0.055921
# wd1                                             -0.090935
# request                                         -0.102674
# Hour                                            -0.219941
# Request/Supply                                  -0.264265
# long_waiting                                    -0.502937
# longwait_percent1                               -0.670419
# longwait_percent2                               -0.677046
# longwait_percent4                               -0.677663
# longwait_percent3                               -0.678210
# Name: accept_rate, dtype: float64

# %% [raw]
# Comment: The correlation between pricing and accept_rate_timeT (previous 20-min accept rate) is strongly negative. This is *NOT* quite intuitive, because increasing in Pricing tends to motivate drivers to get on our platform and accept orders more frequently (supply increased) while decreasing number of requests (demand decreased), which should increase acceptance rate ( = # of accepted orders/# of requests). In addition, the correlation between accept_rate and longwait_percent1 is highest, which reflects the fact that requests occuring in the 2nd half of a 20-min period (I meant, in [10, 20]) matters much more to acceptance rate in the next 20-min period than those requests in [0,10]. The absolute number of orders which were taken too long to be accepted (long_waiting) also has a strong positive correlation with Pricing, which is again easy to understand (merchants tend to accept higher price due to external factors like bad weather (rainny, too hot) or lengths of delivery trips (too far). Note that it's quite interesting to observe the strong correlation between Tuesday and Pricing, which is not intuitively easy to explain why.

# %% [markdown]
# # Random Forest Algorithm and Model Evaluations using Cross-Validation

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder  
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.externals import joblib


forest_reg = RandomForestRegressor()
#Obtain the Random Forest Regression Model using the train sets
forest_model = forest_reg.fit(train_X, train_Y.ravel())
Ypred2 = forest_model.predict(Xtest)

lin_reg = LinearRegression()
linreg_model = lin_reg.fit(train_X, train_Y.ravel())
Ypred3 = linreg_model.predict(Xtest)

joblib.dump(linreg_model, 'LinReg_model_AR.csv', protocol=2) #save the Lin-Reg model into the file named "LinReg_model.pkl"
joblib.dump(forest_model, 'Forest_Model_AR.csv', protocol=2) #save the RF model into the file named "Forest_model.pkl"


lin_mse = mean_squared_error(Ytest, Ypred2)
forest_rmse = np.sqrt(lin_mse)
print("Root Mean Square Error of RF Algo:\t",forest_rmse)

lin_mse2 = mean_squared_error(Ytest, Ypred3)
lin_rmse = np.sqrt(lin_mse2)
print("Root Mean Square Error of Linear Regression Algo:\t", lin_rmse)

#Evaluate RF algo on the whole training set by cross-validation
scores = cross_val_score(forest_reg, train_X, train_Y.ravel(), scoring = "neg_mean_squared_error", cv = 10)
forest_rmse_scores = np.sqrt(-scores)

#Evaluate RF algo on the whole test set by cross-validation
scores3 = cross_val_score(forest_reg, Xtest, Ytest.ravel(), scoring = "neg_mean_squared_error", cv = 10)
forest_rmse_scores3 = np.sqrt(-scores3)

#Evaluate Lin-Reg algo on the whole training set by cross-validation with k = 50 folds
scores2 = cross_val_score(lin_reg, train_X, train_Y.ravel(), scoring = "neg_mean_squared_error", cv = 10)
linreg_rmse_scores2 = np.sqrt(-scores2)

#Evaluate Lin-Reg algo on the test set by cross-validation
scores4 = cross_val_score(lin_reg, Xtest, Ytest.ravel(), scoring = "neg_mean_squared_error", cv = 10)
linreg_rmse_scores4 = np.sqrt(-scores4)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard", scores.std())
    print("Max:", scores.max())
    print("Min:", scores.min())

display_scores(linreg_rmse_scores2)
display_scores(linreg_rmse_scores4)
lin_mae_RF = mean_absolute_error(Ytest, Ypred2)
lin_mae_LR = mean_absolute_error(Ytest, Ypred3)

# display_scores(Accept_rate_prediction)
# print("Mean Square Error:\t", linreg_rmse_scores2)
# print("Mean Absolute Error:\t", lin_mae)
# Out:
# Root Mean Square Error of RF Algo:	 0.0642034489374
# Root Mean Square Error of Linear Regression Algo:	 0.0596156868056
# Scores: [ 0.0604544   0.05998684  0.0669917   0.05900586  0.05670346  0.05710712
#   0.06771698  0.06268166  0.05831281  0.07541041]
# Mean: 0.0624371229392
# Standard 0.00563018121526
# Max: 0.0754104112358
# Min: 0.0567034594764
# Scores: [ 0.04659366  0.06794019  0.07100747  0.05820386  0.06165992  0.05306184
#   0.06218072  0.05445435  0.06362233  0.06404962]
# Mean: 0.0602773965271
# Standard 0.00694493762257
# Max: 0.0710074696513
# Min: 0.0465936579765

# %% [markdown]
# Comment: We generated Random Forest and Linear Regression model using the same train and test sets generated in the first slide. We then compute the RMSE of each model, as well as the RMSE using cross-validation with 50 folds. In both ways, RF performs, *at the very least*, as worse as Linear Regression model in terms of the RMSE. Note that because our train and test set is generated *randomly*, there is *NO* guarantee that the random train set and test set include every possible trends that actuallly occured. Thus, sometimes we could improve our model simply by re-run the first slide and this slide to obtain the new RF model.

# %%
Accept_rate = 0.76
Longwait_percent3 = 0.43
Request = 129
Supply = 597
DriverBusyRate = 0.15
Hour = 18/24
# Percentchange = (Supply - 625)/625
wd = [0,0,0,0,0,0,0]
wd[5] = 1

a = np.array([Accept_rate, Longwait_percent3, Request/Supply, DriverBusyRate, Hour])

Xtest = np.array([np.concatenate([a, wd])],  dtype=np.float32)
lin_model = joblib.load('LinReg_model_AR.csv')
forest_model = joblib.load('Forest_Model_AR.csv')

float(lin_model.predict(Xtest)), float(forest_model.predict(Xtest))
# Out:
# (0.759521484375, 0.772627796)

# %% [markdown]
# Comment: When testing with real data, we observed that the Random Forest Regression works much better than either lin-Reg or DNN Regression because it predicts the correct trend of the pricing that we used in the past (although for downward trends, it resuled in overfits, and for upward trends, it resulted in underfit. One possible explanation  might be due to our bign increase/decrease in pricing suddenly that it's hard to predict such magnitude exactly).  testing with real data, we observed that the Random Forest Regression works much better than either lin-Reg or DNN Regression because it predicts the correct trend of the pricing that we used in the past (although for downward trends, it *often* resuled in overfits on the average of 2% - 5%, and for upward trends, it *often* resulted in underfit on the average of 2% - 4%. One possible explanation  might be due to our bign increase/decrease in pricing suddenly that it's hard to predict such magnitude exactly, especially for the extreme case, for example, from 0.85 to 1 or from 1 to 0.85). Note that form some reasons, this model is *extremely* good at predicting downward trend:)
#
# Note that in order to train this model, we would need to compute the feature Request/Supply (the author used card 1943 & 1868 with Excel to compute this ratio, just for convenience), so there should be a BI card mainly for computing this feature, together with the feature DriverBusyRate (currently, we could query DriverBusyRate from *card 1950* - https://bi.ahamove.com/question/1950?order_date=2017-06-04&end_date=2017-06-06&service=HAN-BIKE&time_interval=20). All the remaining features could be queried from the *card 1868* (https://bi.ahamove.com/question/1868?service_id=HAN-BIKE&time_interval=20&order_date=2017-06-04&end_date=2017-06-13).

# %% [markdown]
# Further idea for development: we see that each variable demand and supply could be expressed as a linear combination of certain features, one of them is *pricing* (for example, demand = a_0 + a_1*pricing + a_2 *request + a_3*feature3 where a_0, a_1, a_2, a_3 = parameters to be optimized. Similar to supply = b_0 + b_1*pricing + b_2*online_drivers + b_3*feature4 where b_0, b_1, b_2, b_3 = parameters to be optimized). Now, our goal is to figure out the optimal pricing such that demand = supply, which means we only need to solve for the equation: a_0 + a_1*pricing + a_2 *request + a_3*feature3 = b_0 + b_1*pricing + b_2*online_drivers + b_3*feature4. Now, we could solve for pricing, and then use Scikit-Learn's Lin-Reg built-in function or RandomForest.Regressor to figure out pricing, based on our historical data!
