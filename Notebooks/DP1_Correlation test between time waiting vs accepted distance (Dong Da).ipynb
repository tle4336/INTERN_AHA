# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import numpy.random as rnd
import os

# to make this notebook's output stable across runs
seednumber = rnd.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [raw]
# # Data only for Dong Da district - 1 month from 06/04 - 07/03

# %%
import pandas as pd

datapath = "/Users/tuanle/DynamicPricing/Data/"

Dong_Da_td = pd.read_csv(datapath+"DongDa_ATAD_1month.csv")
df = pd.DataFrame(Dong_Da_td)
foo = df.ix[(df['acceptdist']<5.01) & (df['acceptdist'] >= 1.5) & (df['duration_min'] >= 1)]
foo

#Dong_Da.describe()
# Out:
#       district  duration_min  acceptdist   timewindow
# 3      Đống Đa      1.448525       1.586  04 08:00:00
# 15     Đống Đa      3.470053       1.687  04 08:40:00
# 19     Đống Đa      9.528344       2.564  04 09:00:00
# 20     Đống Đa      1.030445       2.196  04 09:00:00
# 33     Đống Đa     10.747981       2.660  04 09:20:00
# 42     Đống Đa      4.868842       3.062  04 09:20:00
# 44     Đống Đa      1.066713       2.512  04 09:20:00
# 46     Đống Đa      1.563977       3.134  04 09:20:00
# 48     Đống Đa      1.864803       3.362  04 09:20:00
# 50     Đống Đa     12.160553       2.844  04 09:40:00
# 53     Đống Đa      2.387601       2.323  04 09:40:00
# 54     Đống Đa      1.664403       1.803  04 09:40:00
# 56     Đống Đa      1.819621       3.010  04 09:40:00
# 57     Đống Đa      1.196609       1.810  04 09:40:00
# 58     Đống Đa      2.025495       2.325  04 09:40:00
# 60     Đống Đa      2.279537       2.535  04 09:40:00
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
foo.hist(bins = 50, figsize = (15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12573c2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126710438>]], dtype=object)

# %% [raw]
# # Comment: The histograms of accepted distance and accepted time variables do not show any *clear* correlation between  This would be confirmed below with the correlation coefficient < 0.1 below

# %% [markdown]
# # Measure Correlation Coefficients between acceptance rate against other variables

# %%
corr_matrix = foo.corr()
corr_matrix["acceptdist"].sort_values(ascending=False)
# Out:
# acceptdist      1.000000
# duration_min   -0.012556
# Name: acceptdist, dtype: float64

# %%
foo.plot(kind="scatter", x="acceptdist", y="duration_min", alpha=0.1)
