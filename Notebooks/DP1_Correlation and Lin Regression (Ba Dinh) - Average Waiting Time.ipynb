# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import numpy.random as rnd
import os

# to make this notebook's output stable across runs
seednumber = rnd.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [raw]
# # Data only for Dong Da district - 1 month from 06/04 - 07/03

# %%
import pandas as pd

datapath = "/Users/tuanle/DynamicPricing/Data/"

Ba_Dinh = pd.read_csv(datapath+"BaDinh_1month.csv")
Ba_Dinh.accept_rate = Ba_Dinh.accept_rate.shift(-1)
Ba_Dinh =Ba_Dinh.dropna(subset=["accept_rate"])
Ba_Dinh = Ba_Dinh.drop("requests", axis = 1)
Ba_Dinh2 = Ba_Dinh.drop("district", axis = 1)
median = Ba_Dinh2["acceptorder"].median()
Ba_Dinh2.fillna(median, inplace = True)
df = pd.DataFrame(Ba_Dinh2)
foo = df.ix[(df['accept_rate']<1) & (df['acceptorder'] > df.acceptorder.quantile(0.2))]
foo
#Dong_Da.describe()
# Out:
#       average_waiting_time   timewindow  accept_rate  acceptorder
# 3                 0.892962  04 09:00:00     0.777778         13.0
# 4                 2.033699  04 09:20:00     0.875000          7.0
# 5                 4.229304  04 09:40:00     0.812500          7.0
# 6                 4.617674  04 10:00:00     0.608696         13.0
# 7                 5.759633  04 10:20:00     0.545455         14.0
# 8                 6.398884  04 10:40:00     0.636364         12.0
# 9                 7.873636  04 11:00:00     0.375000         14.0
# 12                4.843746  04 12:00:00     0.909091          7.0
# 14                0.403154  04 12:40:00     0.333333          7.0
# 17                0.319921  04 13:40:00     0.666667          8.0
# 20                1.312258  04 14:40:00     0.875000          9.0
# 29                1.019091  04 17:40:00     0.666667          7.0
# 30                3.498074  04 18:00:00     0.694444         24.0
# 31                5.466970  04 18:20:00     0.800000         25.0
# 32                5.363657  04 18:40:00     0.689655         12.0
# 33                3.562021  04 19:00:00     0.411765         20.0
# 34                6.505827  04 19:20:00     0.434783          7.0
# 35                5.401849  04 19:40:00     0.611111         10.0
# 36                2.209118  04 20:00:00     0.900000         11.0
# 38                5.335617  04 20:40:00     0.750000          9.0
# 42                1.756409  05 09:00:00     0.866667          8.0
# 43                2.030552  05 09:20:00     0.608696         13.0
# 44                5.983902  05 09:40:00     0.850000         14.0
# 45                5.993354  05 10:00:00     0.514286         17.0
# 46                5.714331  05 10:20:00     0.680000         18.0
# 47                9.179630  05 10:40:00     0.666667         17.0
# 48                4.918409  05 11:00:00     0.592593         22.0
# 49                5.547072  05 11:20:00     0.833333         16.0
# 50                4.793405  05 11:40:00     0.812500         15.0
# 51                6.107505  05 12:00:00     0.833333         13.0
# ...                    ...          ...          ...          ...
# 1076              1.644584  01 17:00:00     0.909091          7.0
# 1079              2.578411  01 18:00:00     0.888889          9.0
# 1082              1.700354  01 19:00:00     0.928571          9.0
# 1095              0.910627  02 10:40:00     0.714286          7.0
# 1098              1.253795  02 11:40:00     0.909091          9.0
# 1101              1.597048  02 12:40:00     0.833333         11.0
# 1107              1.366929  02 14:40:00     0.666667          8.0
# 1113              0.864719  02 16:40:00     0.875000         11.0
# 1114              0.321591  02 17:00:00     0.727273          7.0
# 1115              4.062829  02 17:20:00     0.857143          8.0
# 1117              3.199424  02 18:00:00     0.900000         11.0
# 1118              0.990295  02 18:20:00     0.823529         18.0
# 1119              3.608480  02 18:40:00     0.909091         14.0
# 1121              1.275122  02 19:20:00     0.666667          7.0
# 1123              1.716076  02 20:00:00     0.857143          7.0
# 1133              0.474542  03 10:20:00     0.941176         14.0
# 1134              1.656397  03 10:40:00     0.888889         16.0
# 1137              1.515434  03 11:40:00     0.812500         10.0
# 1138              1.852123  03 12:00:00     0.769231         13.0
# 1142              1.028579  03 13:20:00     0.800000         12.0
# 1144              0.581941  03 14:00:00     0.947368          9.0
# 1145              1.495783  03 14:20:00     0.850000         18.0
# 1146              2.358679  03 14:40:00     0.909091         17.0
# 1147              2.120688  03 15:00:00     0.933333         20.0
# 1148              1.266386  03 15:20:00     0.916667         14.0
# 1149              0.971154  03 15:40:00     0.933333         22.0
# 1150              1.404997  03 16:00:00     0.923077         14.0
# 1152              0.644455  03 16:40:00     0.941176         17.0
# 1156              1.473993  03 18:00:00     0.944444         10.0
# 1157              1.489907  03 18:20:00     0.727273         17.0
#
# [658 rows x 4 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
foo.hist(bins = 50, figsize = (15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1166a4b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11997d240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119979710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119de1b38>]], dtype=object)

# %% [raw]
# # Comment: The histograms of average_waiting time and acceptance_rate variables show the *STRONG* negative correlations between these two variables (namely, when average_waiting_time is large, the acceptance rate is significantly lower than the case when average_waiting_time_decreases). This would be confirmed below with the strong negative correlation coefficient betweeen average waiting time against acceptance rate variables

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(Ba_Dinh2, test_size=0.3, random_state=seednumber)
Xtrain = train_set['average_waiting_time'].reshape(-1,1)
Ytrain = train_set['accept_rate'].reshape(-1,1)

Xtest = test_set['average_waiting_time'].reshape(-1,1)
Ytest = test_set['accept_rate'].reshape(-1,1)

Ytest1 = test_set.accept_rate
Ytest1.describe(include=all)
# Out:
# count    349.000000
# mean       0.869574
# std        0.145190
# min        0.240000
# 25%        0.800000
# 50%        0.914286
# 75%        1.000000
# max        1.000000
# Name: accept_rate, dtype: float64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

train_set2, test_set2 = train_test_split(foo, test_size=0.3, random_state=seednumber)
Xtrain2 = train_set2['average_waiting_time'].reshape(-1,1)
Ytrain2 = train_set2['accept_rate'].reshape(-1,1)

Xtest2 = test_set2['average_waiting_time'].reshape(-1,1)
Ytest2 = test_set2['accept_rate'].reshape(-1,1)

Ytest2 = test_set2.accept_rate
Ytest2.describe(include=all)
# Out:
# count    198.000000
# mean       0.827049
# std        0.126609
# min        0.240000
# 25%        0.785714
# 50%        0.857143
# 75%        0.923077
# max        0.970588
# Name: accept_rate, dtype: float64

# %% [markdown]
# # Linear Regression - ML model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
result = model.fit(Xtrain, Ytrain)

# %%
from sklearn.linear_model import LinearRegression

model2 = LinearRegression()
result = model2.fit(Xtrain2, Ytrain2)

# %%
Accept_rate_prediction = model.predict(Xtest)
print("Predictions:\t", Accept_rate_prediction)
Accept_rate_prediction2 = model2.predict(Xtest2)
print("Predictions:\t", Accept_rate_prediction2)

# len(Accept_rate_prediction)

Accept_rate_train  = model.predict(Xtrain)
Accept_rate_train2 = model2.predict(Xtrain2)
# Out:
# Predictions:	 [[ 0.91835666]
#  [ 0.93762036]
#  [ 0.92623502]
#  [ 0.92772897]
#  [ 0.93664448]
#  [ 0.93582776]
#  [ 0.89854513]
#  [ 0.87719025]
#  [ 0.93342388]
#  [ 0.88852659]
#  [ 0.91483414]
#  [ 0.82886364]
#  [ 0.92483244]
#  [ 0.909759  ]
#  [ 0.79885243]
#  [ 0.93649037]
#  [ 0.8150296 ]
#  [ 0.84945036]
#  [ 0.90123625]
#  [ 0.75026226]
#  [ 0.94281557]
#  [ 0.93264046]
#  [ 0.80849729]
#  [ 0.8890653 ]
#  [ 0.8656987 ]
#  [ 0.85010062]
#  [ 0.8793261 ]
#  [ 0.91875532]
#  [ 0.93658212]
#  [ 0.91648131]
#  [ 0.91920081]
#  [ 0.85789406]
#  [ 0.93324548]
#  [ 0.80578783]
#  [ 0.8981977 ]
#  [ 0.93893687]
#  [ 0.79348062]
#  [ 0.86352163]
#  [ 0.91474896]
#  [ 0.92583173]
#  [ 0.71340133]
#  [ 0.89814168]
#  [ 0.83671059]
#  [ 0.81092428]
#  [ 0.84075477]
#  [ 0.88278476]
#  [ 0.92694875]
#  [ 0.83779646]
#  [ 0.90434603]
#  [ 0.92692334]
#  [ 0.8842464 ]
#  [ 0.93564678]
#  [ 0.92316409]
#  [ 0.66583659]
#  [ 0.68475512]
#  [ 0.90998556]
#  [ 0.94062882]
#  [ 0.88402287]
#  [ 0.86195532]
#  [ 0.88783535]
#  [ 0.93830722]
#  [ 0.88103927]
#  [ 0.81403977]
#  [ 0.93822787]
#  [ 0.87455417]
#  [ 0.91653698]
#  [ 0.93961758]
#  [ 0.89136457]
#  [ 0.93595817]
#  [ 0.88070856]
#  [ 0.90100717]
#  [ 0.92873417]
#  [ 0.86467542]
#  [ 0.88491264]
#  [ 0.90183564]
#  [ 0.8789538 ]
#  [ 0.88768353]
#  [ 0.91217621]
#  [ 0.80874095]
#  [ 0.86078081]
#  [ 0.82583393]
#  [ 0.73345908]
#  [ 0.91963918]
#  [ 0.91623229]
#  [ 0.93061154]
#  [ 0.91090791]
#  [ 0.92125395]
#  [ 0.92649192]
#  [ 0.90348266]
#  [ 0.89552523]
#  [ 0.92640773]
#  [ 0.93671367]
#  [ 0.75295863]
#  [ 0.93651098]
#  [ 0.85739154]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9f04def8ebee> in <module>()
#       1 Accept_rate_prediction = model.predict(Xtest)
#       2 print("Predictions:\t", Accept_rate_prediction)
# ----> 3 Accept_rate_prediction2 = model2.predict(Xtest2)
#       4 print("Predictions:\t", Accept_rate_prediction2)
#       5
#
# NameError: name 'model2' is not defined

# %%
Ba_Dinh2.plot(kind="scatter", x="average_waiting_time", y="accept_rate", alpha=0.1),
save_fig("average_waiting_time vs_acceptance_rate"),
foo.plot(kind="scatter", x="average_waiting_time", y="accept_rate", alpha=0.1)
# Out:
# Saving figure average_waiting_time vs_acceptance_rate

# %% [markdown]
# # Mean Squared Error & Mean Absolute Error

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

lin_mse = mean_squared_error(Ytest, Accept_rate_prediction)
lin_rmse = np.sqrt(lin_mse) #taking square root of MSE converts the units back to the original units of the output variable

lin_mae = mean_absolute_error(Ytest, Accept_rate_prediction)
print("Mean Square Error:\t",lin_rmse)
print("Mean Absolute Error:\t", lin_mae)


r_squared = r2_score(Ytest, Accept_rate_prediction) #built-in formula for R^2 
print("R^2:\t", r_squared) 

adjusted_Rsquared = 1 - (1-r_squared)*(len(Xtest)-1)/(len(Xtest)-1-1) #formula for adjusted R^2 by theory
print("Adjusted R^2:\t", adjusted_Rsquared) #correct the error when adding more and more independent variables to the linear regression model

lin_mse = mean_squared_error(Ytrain, Accept_rate_train)
lin_rmse = np.sqrt(lin_mse)
print("Mean Squred Error_train:\t", lin_rmse)
# Out:
# Mean Square Error:	 0.117737988931
# Mean Absolute Error:	 0.0904678218388
# R^2:	 0.34051365471
# Adjusted R^2:	 0.338613117692
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-13f1daf56ffb> in <module>()
#      17 print("Adjusted R^2:\t", adjusted_Rsquared) #correct the error when adding more and more independent variables to the linear regression model
#      18
# ---> 19 lin_mse = mean_squared_error(Ytrain, Accept_rate_train)
#      20 lin_rmse = np.sqrt(lin_mse)
#      21 print("Mean Squred Error_train:\t", lin_rmse)
#
# NameError: name 'Accept_rate_train' is not defined

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

lin_mse2 = mean_squared_error(Ytest2, Accept_rate_prediction2)
lin_rmse2 = np.sqrt(lin_mse2) #taking square root of MSE converts the units back to the original units of the output variable

lin_mae2 = mean_absolute_error(Ytest2, Accept_rate_prediction2)
print("Mean Square Error:\t",lin_rmse2)
print("Mean Absolute Error:\t", lin_mae2)


r_squared2 = r2_score(Ytest2, Accept_rate_prediction2) #built-in formula for R^2 
print("R^2:\t", r_squared2) 

adjusted_Rsquared2 = 1 - (1-r_squared2)*(len(Xtest2)-1)/(len(Xtest2)-1-1) #formula for adjusted R^2 by theory
print("Adjusted R^2:\t", adjusted_Rsquared2) #correct the error when adding more and more independent variables to the linear regression model

lin_mse2 = mean_squared_error(Ytrain2, Accept_rate_train2)
lin_rmse2 = np.sqrt(lin_mse2)
print("Mean Squred Error_train:\t", lin_rmse2)
# Out:
# Mean Square Error:	 0.105761089771
# Mean Absolute Error:	 0.0800521082548
# R^2:	 0.298667333527
# Adjusted R^2:	 0.295089105637
# Mean Squred Error_train:	 0.109573160134

# %% [markdown]
# Comment: R^2 and Adjusted R^2 are nearly the same (0.423 vs 0.418). This explains the acceptance rate is only explained roughly 50% by the independent variable average waiting time

# %% [markdown]
# # Measure Correlation Coefficients between acceptance rate against other variables

# %%
corr_matrix = Dong_Da2.corr()
corr_matrix2 = foo.corr()
(corr_matrix["accept_rate"].sort_values(ascending=False), corr_matrix2["accept_rate"].sort_values(ascending=False))
# Out:
# (accept_rate             1.000000
#  acceptorder            -0.084540
#  average_waiting_time   -0.668629
#  Name: accept_rate, dtype: float64, accept_rate             1.000000
#  acceptorder             0.209843
#  average_waiting_time   -0.647740
#  Name: accept_rate, dtype: float64)

# %% [markdown]
# # Save the model into disk and load it with given test set (Xtest, Ytest)

# %%
from sklearn.externals import joblib
filename = 'my_model.sav'
joblib.dump(model, filename)

# load the model from disk
loaded_model = joblib.load(filename)
result = loaded_model.score(Xtest, Ytest) #R^2 result
print(result)
# Out:
# 0.490341024599
