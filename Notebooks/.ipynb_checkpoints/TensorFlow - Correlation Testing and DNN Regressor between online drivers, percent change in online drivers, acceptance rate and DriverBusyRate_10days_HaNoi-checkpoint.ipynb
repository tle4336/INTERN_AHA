# %%
# A linear regression learning algorithm example using TensorFlow library.

from __future__ import print_function

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.contrib import learn
from sklearn import metrics
import random

rng = np.random

# Parameters
num_epochs = 1000
STEPS = 10000
BATCH_SIZE = 1000


#read csv file
datapath = "/Users/tuanle/DynamicPricing/Data/"
Ha_Noi = pd.read_csv(datapath+"OnlineDrivers_HaNoi_10days.csv")
#Add an additional column into the table
# sLength = len(Ha_Noi['accept_rate'])
Ha_Noi['accept_rate_timeT'] = pd.Series(Ha_Noi['accept_rate'], index=Ha_Noi.index)
#Shift the entries in the accept_rate column upward
Ha_Noi.accept_rate = Ha_Noi.accept_rate.shift(-1)
#Drop all the "na" entries in the original table
Ha_Noi = Ha_Noi.dropna(subset = ["longwait_percent4"])
Ha_Noi = Ha_Noi.dropna(subset=["accept_rate"])
Ha_Noi = Ha_Noi.dropna(subset = ["longwait_percent2"])
Ha_Noi = Ha_Noi.drop(Ha_Noi[Ha_Noi.Percentchange_onlinedrivers == 0].index)
Ha_Noi = Ha_Noi.dropna(subset = ["DriverBusyRate"])
Ha_Noi = Ha_Noi.drop(Ha_Noi[Ha_Noi.DriverBusyRate < 0.1].index)
Ha_Noi['log_onlinedrivers'] = pd.Series(np.log(Ha_Noi.online_drivers), index=Ha_Noi.index)

#define normalized function for our dataset
# def normalize(array):
#     return (array - array.mean()) / array.std()

df2 = pd.DataFrame(Ha_Noi)
print(len(df2))


#split the dataset into training and testing sets
train_set, test_set = train_test_split(Ha_Noi, test_size=0.2, random_state = random.randint(20, 200))

# Training Data
train_X =  np.array(train_set[['longwait_percent2', 'accept_rate_timeT','Percentchange_onlinedrivers', 'DriverBusyRate']], dtype=np.float32)
# train_X2 = np.array(train_set['accept_rate_timeT'], dtype=np.float32)
train_Y =  np.array(train_set['accept_rate'], dtype=np.float32)
n_samples = train_X.shape[0]

#Testing Data
Xtest = np.array(test_set[['longwait_percent2', 'accept_rate_timeT','Percentchange_onlinedrivers', 'DriverBusyRate']], dtype=np.float32)
# Xtest2 = np.array(test_set['accept_rate_timeT'], dtype=np.float32)
Ytest = np.array(test_set['accept_rate'], dtype=np.float32)

#Deep Neural Network Regressor 
feature_column1 = learn.infer_real_valued_columns_from_input(train_X)
# feature_column2 = learn.infer_real_valued_columns_from_input(train_X2)
regressor = learn.DNNRegressor(feature_columns = feature_column1, hidden_units= [50,50])
regressor.fit(train_X, train_Y, max_steps= STEPS, batch_size= BATCH_SIZE)
Ypred = regressor.predict_scores(Xtest, as_iterable=True)
Ypred = np.asarray(list(Ypred))
rmse = np.sqrt(((Ypred - Ytest) ** 2).mean(axis=0))
print("Root mean square Error: %.3f" %rmse)
# Out:
# 359
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/tn/4g20x2q119jdjnlf36j_8j_m0000gn/T/tmpr6syfp1v
# INFO:tensorflow:Using config: {'_task_id': 0, '_master': '', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_evaluation_master': '', '_num_worker_replicas': 0, '_task_type': None, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_environment': 'local', '_save_checkpoints_secs': 600, '_model_dir': '/var/folders/tn/4g20x2q119jdjnlf36j_8j_m0000gn/T/tmpr6syfp1v', '_is_chief': True, '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11b79a400>, '_num_ps_replicas': 0, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_session_config': None}
# WARNING:tensorflow:From <ipython-input-56-fabbd3aa113e>:65: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-56-fabbd3aa113e>:65: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-56-fabbd3aa113e>:65: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Applications/anaconda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# /Applications/anaconda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:254: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/tn/4g20x2q119jdjnlf36j_8j_m0000gn/T/tmpr6syfp1v/model.ckpt.
# INFO:tensorflow:loss = 0.655576, step = 1
# INFO:tensorflow:global_step/sec: 398.797
# INFO:tensorflow:loss = 0.00357647, step = 101 (0.252 sec)
# INFO:tensorflow:global_step/sec: 497.357
# INFO:tensorflow:loss = 0.0035468, step = 201 (0.200 sec)
# INFO:tensorflow:global_step/sec: 569.389
# INFO:tensorflow:loss = 0.00352227, step = 301 (0.176 sec)
# INFO:tensorflow:global_step/sec: 504.179
# INFO:tensorflow:loss = 0.00350649, step = 401 (0.198 sec)
# INFO:tensorflow:global_step/sec: 568.757
# INFO:tensorflow:loss = 0.00349178, step = 501 (0.176 sec)
# INFO:tensorflow:global_step/sec: 526.53
# INFO:tensorflow:loss = 0.00348365, step = 601 (0.190 sec)
# INFO:tensorflow:global_step/sec: 542.811
# INFO:tensorflow:loss = 0.00347786, step = 701 (0.184 sec)
# INFO:tensorflow:global_step/sec: 539.231
# INFO:tensorflow:loss = 0.00347275, step = 801 (0.186 sec)
# INFO:tensorflow:global_step/sec: 517.641
# INFO:tensorflow:loss = 0.00346747, step = 901 (0.193 sec)
# INFO:tensorflow:global_step/sec: 550.579
# INFO:tensorflow:loss = 0.00346256, step = 1001 (0.182 sec)
# INFO:tensorflow:global_step/sec: 492.138
# INFO:tensorflow:loss = 0.00345803, step = 1101 (0.202 sec)
# INFO:tensorflow:global_step/sec: 561.848
# INFO:tensorflow:loss = 0.00345373, step = 1201 (0.177 sec)
# INFO:tensorflow:global_step/sec: 530.775
# INFO:tensorflow:loss = 0.00344938, step = 1301 (0.189 sec)
# INFO:tensorflow:global_step/sec: 505.837
# INFO:tensorflow:loss = 0.003445, step = 1401 (0.198 sec)
# INFO:tensorflow:global_step/sec: 518.877
# INFO:tensorflow:loss = 0.00344108, step = 1501 (0.192 sec)
# INFO:tensorflow:global_step/sec: 565.57
# INFO:tensorflow:loss = 0.00343722, step = 1601 (0.177 sec)
# INFO:tensorflow:global_step/sec: 540.926
# INFO:tensorflow:loss = 0.00343345, step = 1701 (0.184 sec)
# INFO:tensorflow:global_step/sec: 468.799
# INFO:tensorflow:loss = 0.00342977, step = 1801 (0.214 sec)
# INFO:tensorflow:global_step/sec: 588.751
# INFO:tensorflow:loss = 0.00342619, step = 1901 (0.170 sec)
# INFO:tensorflow:global_step/sec: 518.291
# INFO:tensorflow:loss = 0.00342267, step = 2001 (0.193 sec)
# INFO:tensorflow:global_step/sec: 525.254
# INFO:tensorflow:loss = 0.00341921, step = 2101 (0.190 sec)
# INFO:tensorflow:global_step/sec: 558.213
# INFO:tensorflow:loss = 0.00341578, step = 2201 (0.179 sec)
# INFO:tensorflow:global_step/sec: 515.414
# INFO:tensorflow:loss = 0.00341224, step = 2301 (0.197 sec)
# INFO:tensorflow:global_step/sec: 462.768
# INFO:tensorflow:loss = 0.00340887, step = 2401 (0.214 sec)
# INFO:tensorflow:global_step/sec: 521.935
# INFO:tensorflow:loss = 0.00340549, step = 2501 (0.190 sec)
# INFO:tensorflow:global_step/sec: 466.727
# INFO:tensorflow:loss = 0.00340216, step = 2601 (0.215 sec)
# INFO:tensorflow:global_step/sec: 595.859
# INFO:tensorflow:loss = 0.00339884, step = 2701 (0.167 sec)
# INFO:tensorflow:global_step/sec: 592.743
# INFO:tensorflow:loss = 0.00339553, step = 2801 (0.169 sec)
# INFO:tensorflow:global_step/sec: 592.228
# INFO:tensorflow:loss = 0.00339227, step = 2901 (0.169 sec)
# INFO:tensorflow:global_step/sec: 551.989
# INFO:tensorflow:loss = 0.00338903, step = 3001 (0.181 sec)
# INFO:tensorflow:global_step/sec: 550.467
# INFO:tensorflow:loss = 0.00338582, step = 3101 (0.182 sec)
# INFO:tensorflow:global_step/sec: 599.992
# INFO:tensorflow:loss = 0.00338261, step = 3201 (0.167 sec)
# INFO:tensorflow:global_step/sec: 598.333
# INFO:tensorflow:loss = 0.00337946, step = 3301 (0.167 sec)
# INFO:tensorflow:global_step/sec: 594.746
# INFO:tensorflow:loss = 0.00337632, step = 3401 (0.168 sec)
# INFO:tensorflow:global_step/sec: 589.167
# INFO:tensorflow:loss = 0.00337321, step = 3501 (0.170 sec)
# INFO:tensorflow:global_step/sec: 553.211
# INFO:tensorflow:loss = 0.0033701, step = 3601 (0.180 sec)
# INFO:tensorflow:global_step/sec: 574.991
# INFO:tensorflow:loss = 0.00336701, step = 3701 (0.174 sec)
# INFO:tensorflow:global_step/sec: 578.965
# INFO:tensorflow:loss = 0.00336396, step = 3801 (0.173 sec)
# INFO:tensorflow:global_step/sec: 591.65
# INFO:tensorflow:loss = 0.00336092, step = 3901 (0.169 sec)
# INFO:tensorflow:global_step/sec: 592.898
# INFO:tensorflow:loss = 0.00335792, step = 4001 (0.169 sec)
# INFO:tensorflow:global_step/sec: 603.577
# INFO:tensorflow:loss = 0.00335496, step = 4101 (0.166 sec)
# INFO:tensorflow:global_step/sec: 533.741
# INFO:tensorflow:loss = 0.00335205, step = 4201 (0.187 sec)
# INFO:tensorflow:global_step/sec: 585.466
# INFO:tensorflow:loss = 0.00334914, step = 4301 (0.170 sec)
# INFO:tensorflow:global_step/sec: 582.804
# INFO:tensorflow:loss = 0.00334625, step = 4401 (0.172 sec)
# INFO:tensorflow:global_step/sec: 599.413
# INFO:tensorflow:loss = 0.00334337, step = 4501 (0.167 sec)
# INFO:tensorflow:global_step/sec: 588.786
# INFO:tensorflow:loss = 0.00334051, step = 4601 (0.170 sec)
# INFO:tensorflow:global_step/sec: 593.275
# INFO:tensorflow:loss = 0.00333767, step = 4701 (0.169 sec)
# INFO:tensorflow:global_step/sec: 572.701
# INFO:tensorflow:loss = 0.00333484, step = 4801 (0.174 sec)
# INFO:tensorflow:global_step/sec: 593.426
# INFO:tensorflow:loss = 0.00333206, step = 4901 (0.169 sec)
# INFO:tensorflow:global_step/sec: 569.795
# INFO:tensorflow:loss = 0.00332927, step = 5001 (0.176 sec)
# INFO:tensorflow:global_step/sec: 590.985
# INFO:tensorflow:loss = 0.00332648, step = 5101 (0.169 sec)
# INFO:tensorflow:global_step/sec: 594.717
# INFO:tensorflow:loss = 0.00332375, step = 5201 (0.168 sec)
# INFO:tensorflow:global_step/sec: 599.226
# INFO:tensorflow:loss = 0.00332099, step = 5301 (0.167 sec)
# INFO:tensorflow:global_step/sec: 521.766
# INFO:tensorflow:loss = 0.00331829, step = 5401 (0.191 sec)
# INFO:tensorflow:global_step/sec: 582.024
# INFO:tensorflow:loss = 0.0033156, step = 5501 (0.172 sec)
# INFO:tensorflow:global_step/sec: 588.907
# INFO:tensorflow:loss = 0.00331288, step = 5601 (0.170 sec)
# INFO:tensorflow:global_step/sec: 589.825
# INFO:tensorflow:loss = 0.0033102, step = 5701 (0.169 sec)
# INFO:tensorflow:global_step/sec: 595.912
# INFO:tensorflow:loss = 0.00330752, step = 5801 (0.168 sec)
# INFO:tensorflow:global_step/sec: 550.315
# INFO:tensorflow:loss = 0.00330485, step = 5901 (0.182 sec)
# INFO:tensorflow:global_step/sec: 592.958
# INFO:tensorflow:loss = 0.00330214, step = 6001 (0.168 sec)
# INFO:tensorflow:global_step/sec: 589.258
# INFO:tensorflow:loss = 0.00329942, step = 6101 (0.169 sec)
# INFO:tensorflow:global_step/sec: 591.198
# INFO:tensorflow:loss = 0.00329675, step = 6201 (0.170 sec)
# INFO:tensorflow:global_step/sec: 575.148
# INFO:tensorflow:loss = 0.00329413, step = 6301 (0.173 sec)
# INFO:tensorflow:global_step/sec: 591.345
# INFO:tensorflow:loss = 0.00329152, step = 6401 (0.169 sec)
# INFO:tensorflow:global_step/sec: 566.146
# INFO:tensorflow:loss = 0.00328893, step = 6501 (0.176 sec)
# INFO:tensorflow:global_step/sec: 589.32
# INFO:tensorflow:loss = 0.00328634, step = 6601 (0.170 sec)
# INFO:tensorflow:global_step/sec: 588.547
# INFO:tensorflow:loss = 0.00328378, step = 6701 (0.170 sec)
# INFO:tensorflow:global_step/sec: 595.107
# INFO:tensorflow:loss = 0.00328124, step = 6801 (0.168 sec)
# INFO:tensorflow:global_step/sec: 590.667
# INFO:tensorflow:loss = 0.0032787, step = 6901 (0.169 sec)
# INFO:tensorflow:global_step/sec: 586.239
# INFO:tensorflow:loss = 0.00327612, step = 7001 (0.171 sec)
# INFO:tensorflow:global_step/sec: 576.136
# INFO:tensorflow:loss = 0.00327358, step = 7101 (0.174 sec)
# INFO:tensorflow:global_step/sec: 531.048
# INFO:tensorflow:loss = 0.00327107, step = 7201 (0.188 sec)
# INFO:tensorflow:global_step/sec: 549.487
# INFO:tensorflow:loss = 0.00326839, step = 7301 (0.182 sec)
# INFO:tensorflow:global_step/sec: 546.735
# INFO:tensorflow:loss = 0.00326581, step = 7401 (0.183 sec)
# INFO:tensorflow:global_step/sec: 581.26
# INFO:tensorflow:loss = 0.00326326, step = 7501 (0.172 sec)
# INFO:tensorflow:global_step/sec: 585.247
# INFO:tensorflow:loss = 0.00326071, step = 7601 (0.171 sec)
# INFO:tensorflow:global_step/sec: 538.245
# INFO:tensorflow:loss = 0.00325821, step = 7701 (0.186 sec)
# INFO:tensorflow:global_step/sec: 586.369
# INFO:tensorflow:loss = 0.00325567, step = 7801 (0.170 sec)
# INFO:tensorflow:global_step/sec: 591.02
# INFO:tensorflow:loss = 0.00325319, step = 7901 (0.169 sec)
# INFO:tensorflow:global_step/sec: 573.819
# INFO:tensorflow:loss = 0.00325075, step = 8001 (0.174 sec)
# INFO:tensorflow:global_step/sec: 593.747
# INFO:tensorflow:loss = 0.00324821, step = 8101 (0.168 sec)
# INFO:tensorflow:global_step/sec: 580.943
# INFO:tensorflow:loss = 0.00324578, step = 8201 (0.173 sec)
# INFO:tensorflow:global_step/sec: 581.994
# INFO:tensorflow:loss = 0.00324333, step = 8301 (0.172 sec)
# INFO:tensorflow:global_step/sec: 580.828
# INFO:tensorflow:loss = 0.0032409, step = 8401 (0.172 sec)
# INFO:tensorflow:global_step/sec: 591.338
# INFO:tensorflow:loss = 0.00323849, step = 8501 (0.169 sec)
# INFO:tensorflow:global_step/sec: 585.582
# INFO:tensorflow:loss = 0.00323608, step = 8601 (0.171 sec)
# INFO:tensorflow:global_step/sec: 574.786
# INFO:tensorflow:loss = 0.00323366, step = 8701 (0.174 sec)
# INFO:tensorflow:global_step/sec: 554.57
# INFO:tensorflow:loss = 0.00323126, step = 8801 (0.181 sec)
# INFO:tensorflow:global_step/sec: 573.316
# INFO:tensorflow:loss = 0.00322884, step = 8901 (0.174 sec)
# INFO:tensorflow:global_step/sec: 578.63
# INFO:tensorflow:loss = 0.00322648, step = 9001 (0.173 sec)
# INFO:tensorflow:global_step/sec: 581.354
# INFO:tensorflow:loss = 0.00322412, step = 9101 (0.172 sec)
# INFO:tensorflow:global_step/sec: 584.672
# INFO:tensorflow:loss = 0.00322178, step = 9201 (0.171 sec)
# INFO:tensorflow:global_step/sec: 583.949
# INFO:tensorflow:loss = 0.00321948, step = 9301 (0.171 sec)
# INFO:tensorflow:global_step/sec: 530.408
# INFO:tensorflow:loss = 0.00321721, step = 9401 (0.189 sec)
# INFO:tensorflow:global_step/sec: 578.038
# INFO:tensorflow:loss = 0.0032149, step = 9501 (0.173 sec)
# INFO:tensorflow:global_step/sec: 581.947
# INFO:tensorflow:loss = 0.00321266, step = 9601 (0.171 sec)
# INFO:tensorflow:global_step/sec: 588.145
# INFO:tensorflow:loss = 0.00321036, step = 9701 (0.170 sec)
# INFO:tensorflow:global_step/sec: 582.418
# INFO:tensorflow:loss = 0.00320811, step = 9801 (0.172 sec)
# INFO:tensorflow:global_step/sec: 579.972
# INFO:tensorflow:loss = 0.00320587, step = 9901 (0.173 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /var/folders/tn/4g20x2q119jdjnlf36j_8j_m0000gn/T/tmpr6syfp1v/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00320368.
# WARNING:tensorflow:From /Applications/anaconda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:744: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from /var/folders/tn/4g20x2q119jdjnlf36j_8j_m0000gn/T/tmpr6syfp1v/model.ckpt-10000
# Root mean square Error: 0.048

# %% [markdown]
# # Correlation testing between acceptance rate, online drivers and percent change in online drivers

# %%
corr_matrix = Ha_Noi.corr()
corr_matrix["accept_rate"].sort_values(ascending=False)

# %matplotlib inline
# import matplotlib.pyplot as plt
# df2.hist(bins = 50, figsize = (15, 15))
# Out:
# accept_rate                    1.000000
# accept_rate_timeT              0.766752
# log_onlinedrivers              0.335491
# online_drivers                 0.323698
# Percentchange_onlinedrivers    0.265362
# DriverBusyRate                -0.081558
# request                       -0.089699
# long_waiting                  -0.584625
# longwait_percent1             -0.736557
# longwait_percent2             -0.743146
# longwait_percent4             -0.743859
# longwait_percent3             -0.744769
# Name: accept_rate, dtype: float64

# %% [raw]
# Comment: The correlation coefficient between online drivers and accept_rate is quite week (0.300). This is probably due to the fact that online drivers are "pure" numbers, compared to accept_rate, which is in percentage. In addition, the correlation coefficient between accept_rate and Percentchange_onlinedrivers is even lower than 0.3 (even when we purposely remove all potential outliers, such as those when Percent <= -1 or Percent = 0).

# %% [markdown]
# # Random Forest Algorithm and Model Evaluations using Cross-Validation

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder  
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


forest_reg = RandomForestRegressor()
forest_reg.fit(train_X, train_Y.ravel())
Ypred2 = forest_reg.predict(Xtest)

lin_reg = LinearRegression()


lin_mse = mean_squared_error(Ytest, Ypred2)
forest_rmse = np.sqrt(lin_mse)
print("Root Mean Square Error of RF Algo:\t",forest_rmse)

lin_mse2 = mean_squared_error(Ytest, Ypred)
lin_rmse = np.sqrt(lin_mse2)
print("Root Mean Square Error of DNN Algo:\t", lin_rmse)

#Evaluate RF algo on the whole training set by cross-validation
scores = cross_val_score(forest_reg, train_X, train_Y.ravel(), scoring = "neg_mean_squared_error", cv = 10)
forest_rmse_scores = np.sqrt(-scores)

#Evaluate RF algo on the whole test set by cross-validation
scores3 = cross_val_score(forest_reg, Xtest, Ytest.ravel(), scoring = "neg_mean_squared_error", cv = 10)
forest_rmse_scores3 = np.sqrt(-scores3)

#Evaluate Lin-Reg algo on the whole training set by cross-validation with k = 50 folds
scores2 = cross_val_score(lin_reg, train_X, train_Y.ravel(), scoring = "neg_mean_squared_error", cv = len(train_X))
linreg_rmse_scores2 = np.sqrt(-scores2)

#Evaluate Lin-Reg algo on the test set by cross-validation
scores4 = cross_val_score(lin_reg, Xtest, Ytest.ravel(), scoring = "neg_mean_squared_error", cv = len(Xtest))
linreg_rmse_scores4 = np.sqrt(-scores4)


def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard", scores.std())
    print("Max:", scores.max())
    print("Min:", scores.min())

display_scores(linreg_rmse_scores2)
display_scores(linreg_rmse_scores4)
lin_mae_RF = mean_absolute_error(Ytest, Ypred)
lin_mae_DNN = mean_absolute_error(Ytest, Ypred2)

# display_scores(Accept_rate_prediction)
# print("Mean Square Error:\t", linreg_rmse_scores2)
# print("Mean Absolute Error:\t", lin_mae)
# Out:
# Root Mean Square Error of RF Algo:	 0.0479646140219
# Root Mean Square Error of DNN Algo:	 0.0484971
# Scores: [  1.49921952e-02   5.24170954e-02   5.26724005e-02   2.92611346e-02
#    1.45782964e-02   2.79729234e-02   2.55782253e-02   4.53886508e-02
#    5.69399600e-02   1.04844831e-02   2.84607175e-02   1.65080457e-01
#    4.44059223e-02   2.41274281e-02   9.49695115e-04   5.56148100e-03
#    2.23169518e-04   1.14140786e-02   5.92193886e-02   3.00681501e-02
#    9.21124540e-02   3.75927412e-03   5.00135469e-02   8.45393281e-02
#    5.55044475e-03   2.35133487e-01   2.60741736e-02   7.19403784e-02
#    1.11308526e-02   2.51296419e-02   5.76826247e-02   5.21830875e-02
#    7.03167819e-02   3.56306026e-03   1.04477988e-01   7.08061587e-02
#    3.68297783e-02   3.86519696e-02   4.01505412e-02   3.45718963e-02
#    1.66753051e-02   1.88675348e-02   1.01839854e-01   1.71553144e-02
#    2.99609165e-02   2.94957953e-02   3.80529463e-03   7.54459159e-02
#    6.09166671e-02   9.95185710e-02   5.69595077e-02   1.31114782e-02
#    2.46229967e-01   4.44064556e-03   1.30306211e-02   6.16983262e-02
#    6.96776751e-02   6.96145640e-02   3.03122470e-02   1.52225013e-02
#    8.63034276e-03   1.73210544e-02   2.09295698e-04   8.65042755e-02
#    7.23487868e-02   2.80865368e-02   9.31866419e-02   1.65979774e-02
#    4.25727107e-02   1.15326470e-02   4.16018013e-02   6.35722234e-02
#    1.21941702e-02   6.63319764e-02   1.24297780e-01   1.52240050e-02
#    2.03523094e-02   1.48366640e-02   1.43164383e-01   1.50363358e-02
#    5.33566823e-03   2.06342865e-02   6.59804666e-02   2.24480932e-02
#    5.50336038e-02   2.79871661e-02   7.00141563e-02   3.54997796e-02
#    8.75836937e-02   5.31377395e-02   8.03622937e-02   1.62182883e-02
#    1.33163775e-02   5.25942522e-02   5.18407353e-02   8.09494699e-02
#    1.95195107e-02   7.71681055e-03   3.03975882e-02   5.55315409e-02
#    2.28147287e-02   1.16102187e-02   2.99844111e-02   1.17441312e-01
#    7.64879929e-02   2.36713660e-02   5.05322525e-03   7.31828417e-02
#    2.69822182e-01   4.66076475e-02   4.53218166e-02   6.60973198e-02
#    9.10701481e-02   1.95071566e-02   4.53225612e-03   1.51522577e-03
#    5.92305677e-03   3.20573981e-02   9.92989705e-03   5.32282714e-02
#    4.90859268e-02   2.29289056e-02   5.65056287e-02   5.48382209e-02
#    8.00859511e-02   6.81182508e-03   9.03632690e-02   1.63315699e-02
#    4.73716062e-02   2.29457773e-02   2.99118244e-02   6.41767613e-02
#    2.68466814e-02   1.65679755e-02   3.12212660e-02   1.69151221e-02
#    8.36855200e-02   1.56293692e-02   6.09653507e-03   1.78069038e-02
#    3.85847313e-02   9.66694887e-02   5.26437900e-02   7.93731181e-03
#    3.57645352e-02   6.30447510e-02   1.66430640e-02   2.94455870e-02
#    1.69065512e-02   5.21330325e-02   6.52591934e-02   2.80311747e-02
#    9.36500044e-04   8.66249437e-02   2.78853729e-02   1.45571051e-02
#    1.80940723e-02   5.08936343e-02   3.11701374e-02   9.74824330e-02
#    3.75703399e-02   6.05487670e-02   2.48498172e-02   5.40945372e-02
#    1.67040592e-02   1.83292662e-03   1.19174597e-02   3.39181377e-02
#    2.57734512e-02   1.11284327e-01   5.79559542e-02   2.01127522e-02
#    4.42552239e-02   3.93410986e-02   4.98670146e-02   2.71072845e-02
#    1.50614206e-02   3.85010755e-02   7.11138788e-04   6.78229239e-02
#    4.53612494e-03   5.58994707e-02   1.52344517e-02   6.47658614e-02
#    4.49499269e-02   1.00689399e-01   1.36701008e-02   4.88190039e-03
#    3.08610172e-02   8.48129312e-03   8.56244718e-02   2.19657429e-02
#    1.69045926e-01   2.03215222e-02   4.79995213e-02   2.57005750e-02
#    5.37141878e-02   8.09265944e-02   3.98814334e-02   1.12505881e-01
#    5.70630535e-03   3.27400883e-02   1.34940808e-02   3.66359283e-02
#    5.59703031e-02   8.50193213e-03   4.16224282e-03   2.43142971e-02
#    3.72227335e-02   3.86085076e-02   6.48093153e-02   1.88030103e-02
#    2.35965964e-02   1.97077702e-02   7.46843815e-02   3.00869873e-02
#    2.32305100e-02   3.21833004e-02   2.73679660e-01   5.98466650e-02
#    2.50618019e-02   5.34964178e-02   5.82713157e-02   4.56186098e-02
#    2.52882403e-02   3.36775545e-01   2.36609956e-02   1.02322274e-02
#    1.12454688e-02   7.78984553e-03   1.33057692e-02   2.99055854e-02
#    3.26875763e-02   8.87953995e-02   1.84963068e-01   1.71441882e-02
#    1.25748792e-03   3.59668153e-02   1.03596523e-02   8.73151802e-03
#    4.18259318e-02   1.10191419e-01   2.36184272e-02   2.78758833e-02
#    4.80739491e-02   2.22823253e-02   2.45964417e-02   1.97548010e-03
#    2.96877908e-02   4.45482457e-02   3.73415945e-02   7.31135246e-02
#    6.32829182e-02   5.27380412e-02   1.80401702e-02   9.09957802e-03
#    2.57648971e-02   2.13904710e-02   2.35180084e-02   3.45317113e-02
#    1.24767479e-02   5.26777723e-02   2.08138772e-02   1.45975371e-02
#    2.16092511e-02   3.92720220e-02   9.73936966e-03   3.08524467e-02
#    1.57635141e-02   3.41742211e-02   3.07820054e-02   2.86321239e-03
#    1.08507207e-02   1.07168390e-03   5.98117359e-03   4.73946627e-02
#    1.93768376e-02   4.45581694e-02   1.35586315e-01   4.09397657e-02
#    9.90316131e-03   7.91810391e-02   1.80951881e-02   5.05616561e-02
#    9.93629088e-03   2.68100753e-02   4.11801597e-02]
# Mean: 0.0431594457197
# Standard 0.0438552898574
# Max: 0.33677554478
# Min: 0.000209295698318
# Scores: [ 0.0017749   0.05563777  0.00328265  0.06102786  0.03662595  0.01274152
#   0.00244984  0.0301832   0.01567469  0.08279671  0.01140173  0.02285776
#   0.06732066  0.03976055  0.01653759  0.02511915  0.072488    0.05669756
#   0.00679585  0.05122051  0.08714304  0.06438326  0.06522449  0.01534953
#   0.11311181  0.0565033   0.0753913   0.06206902  0.06562443  0.03471597
#   0.03986795  0.06176198  0.04731574  0.03317625  0.06953277  0.01478759
#   0.08324094  0.0527662   0.02246561  0.01202588  0.01301615  0.05614732
#   0.03006213  0.09052043  0.01659702  0.02158236  0.08407814  0.04093397
#   0.01192492  0.04386087  0.01808156  0.02292876  0.04869565  0.01359161
#   0.11616427  0.00463852  0.00594447  0.03161141  0.06123245  0.08317853
#   0.00672018  0.04903948  0.03789926  0.06303676  0.03041532  0.00013749
#   0.00617258  0.07471009  0.06432196  0.01181093  0.09483171  0.05327799]
# Mean: 0.0424446638374
# Standard 0.0288647123922
# Max: 0.116164265065
# Min: 0.000137492499904
